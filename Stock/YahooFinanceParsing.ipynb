# %%
from googlefinance import getQuotes
import json

# %%
getQuotes('MSFT')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-30-7f38da640912> in <module>
# ----> 1 getQuotes('MSFT')
#
# C:\Anaconda3\lib\site-packages\googlefinance\__init__.py in getQuotes(symbols)
#      68     if type(symbols) == type('str'):
#      69         symbols = [symbols]
# ---> 70     content = json.loads(request(symbols))
#      71     return replaceKeys(content);
#      72
#
# C:\Anaconda3\lib\site-packages\googlefinance\__init__.py in request(symbols)
#      31     url = buildUrl(symbols)
#      32     req = Request(url)
# ---> 33     resp = urlopen(req)
#      34     # remove special symbols such as the pound symbol
#      35     content = resp.read().decode('ascii', 'ignore').strip()
#
# C:\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# ...

# %%
microsoft = Share('MSFT')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# C:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# C:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ...

# %%
microsoft
