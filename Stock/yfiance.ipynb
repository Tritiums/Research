# %%
import pandas as pd
import yfinance as yf

# %%
tsla_df = yf.download('TSLA', 
                      start='2019-01-01', 
                      end='2019-12-31', 
                      progress=False)
tsla_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31  337.790009  339.209991  325.260010  332.799988  332.799988
# 2019-01-02  306.100006  315.130005  298.799988  310.119995  310.119995
# 2019-01-03  307.000000  309.399994  297.380005  300.359985  300.359985
# 2019-01-04  306.000000  318.000000  302.730011  317.690002  317.690002
# 2019-01-07  321.720001  336.739990  317.750000  334.959991  334.959991
#
#               Volume
# Date
# 2018-12-31   6302300
# 2019-01-02  11658600
# 2019-01-03   6965200
# 2019-01-04   7394100
# 2019-01-07   7551200

# %%
microsoft_df = yf.download('MSFT', start='2019-01-01', end='2019-12-31',progress=False)

# %%
microsoft_df.to_csv('output.csv')

# %%
msft = yf.Ticker("MSFT")
msft.info['open']
# Out:
# 180.62

# %%
msft.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
# ...

# %%
for item in tsla_df:
    print(item)
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %%
tsla_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31  337.790009  339.209991  325.260010  332.799988  332.799988
# 2019-01-02  306.100006  315.130005  298.799988  310.119995  310.119995
# 2019-01-03  307.000000  309.399994  297.380005  300.359985  300.359985
# 2019-01-04  306.000000  318.000000  302.730011  317.690002  317.690002
# 2019-01-07  321.720001  336.739990  317.750000  334.959991  334.959991
# ...                ...         ...         ...         ...         ...
# 2019-12-23  411.779999  422.010010  410.000000  419.220001  419.220001
# 2019-12-24  418.359985  425.470001  412.690002  425.250000  425.250000
# 2019-12-26  427.910004  433.480011  426.350006  430.940002  430.940002
# 2019-12-27  435.000000  435.309998  426.109985  430.380005  430.380005
# 2019-12-30  428.790009  429.000000  409.260010  414.700012  414.700012
#
#               Volume
# Date
# 2018-12-31   6302300
# 2019-01-02  11658600
# 2019-01-03   6965200
# ...

# %%
len(tsla_df)
# Out:
# 252

# %%
tsla_df['Open']
# Out:
# Date
# 2018-12-31    337.790009
# 2019-01-02    306.100006
# 2019-01-03    307.000000
# 2019-01-04    306.000000
# 2019-01-07    321.720001
#                  ...
# 2019-12-23    411.779999
# 2019-12-24    418.359985
# 2019-12-26    427.910004
# 2019-12-27    435.000000
# 2019-12-30    428.790009
# Name: Open, Length: 252, dtype: float64

# %%
for index, row in tsla_df.iterrows():
    i = index
    r = row
    print(index)
    print(row)
    print(type(index))
    print(type(row))
    print(type(row[0]))
    print(len(row))
# Out:
# 2018-12-31 00:00:00
# Open         3.377900e+02
# High         3.392100e+02
# Low          3.252600e+02
# Close        3.328000e+02
# Adj Close    3.328000e+02
# Volume       6.302300e+06
# Name: 2018-12-31 00:00:00, dtype: float64
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas.core.series.Series'>
# <class 'numpy.float64'>
# 6
# 2019-01-02 00:00:00
# Open         3.061000e+02
# High         3.151300e+02
# Low          2.988000e+02
# Close        3.101200e+02
# Adj Close    3.101200e+02
# Volume       1.165860e+07
# Name: 2019-01-02 00:00:00, dtype: float64
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas.core.series.Series'>
# <class 'numpy.float64'>
# 6
# 2019-01-03 00:00:00
# Open         3.070000e+02
# High         3.094000e+02
# Low          2.973800e+02
# Close        3.003600e+02
# Adj Close    3.003600e+02
# Volume       6.965200e+06
# Name: 2019-01-03 00:00:00, dtype: float64
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# ...

# %%
a = ['a', 'b', 'c']
m = 1
a.append(1)

# %%
ml = []

# %%
ml.append(m)

# %%
ml.extend(a)

# %%
ml
# Out:
# [1, 'a', 'b', 'c', 1]

# %%
str(i)
# Out:
# '2019-12-30 00:00:00'

# %%
r
# Out:
# Open         4.287900e+02
# High         4.290000e+02
# Low          4.092600e+02
# Close        4.147000e+02
# Adj Close    4.147000e+02
# Volume       1.258640e+07
# Name: 2019-12-30 00:00:00, dtype: float64

# %%
list(r)
# Out:
# [428.7900085449219,
#  429.0,
#  409.260009765625,
#  414.70001220703125,
#  414.70001220703125,
#  12586400.0]

# %%
tsla_df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x0000019814733D68>

# %%
tsla_df.shape
# Out:
# (252, 6)
