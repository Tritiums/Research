# %%
import scipy
from scipy import stats
import scipy.integrate as spi
import numpy as np
import pylab as pl
import pandas as pd
import math
import xlrd
import sys
import time

# %matplotlib inline

# %%
filename = 'coronaData.xlsx'
book = xlrd.open_workbook(filename)
print('Source file: ' + sys.path[0] + filename + ' loaded!')

#Extraction
nsheets = book.nsheets

sheet_names = book.sheet_names()
sheets = {}

for sheet_name in sheet_names:    
    nrows = book.sheet_by_name(sheet_name).nrows
    current_header = book.sheet_by_name(sheet_name).row_values(0) 
    current_data = [book.sheet_by_name(sheet_name).row_values(i) for i in range(1, nrows)]
    sheets[sheet_name] = pd.DataFrame(current_data, columns = current_header)   #DataFrame Construction
#Feedback
print('Data Extracted!')
# Out:
# Source file: E:\Chuan\Documents\GitHub\Research\SEIRcoronaData.xlsx loaded!
# Data Extracted!

# %%
sheet_names
# Out:
# ['Italy',
#  'Iran',
#  'Switzerland',
#  'UK',
#  'SouthKorea',
#  'France',
#  'Germany',
#  'Spain',
#  'US',
#  'China']

# %%
chosen_country = 'France'
population = 64 * math.pow(10,6)
infected_initial = 11
removed_initial = 2

start_count_day = 21

# Population
# China(Wuhan): 7e6, Italy: 49e6, Germany 81e6, Spain: 47e6, France: 64e6, US: 327e6, SouthKorea: 506e6

# %%
sheets[chosen_country]
# Out:
#                  infected  recovered  death
# 0   22-JAN-2020       0.0        0.0    0.0
# 1   23-JAN-2020       0.0        0.0    0.0
# 2   24-JAN-2020       2.0        0.0    0.0
# 3   25-JAN-2020       3.0        0.0    0.0
# 4   26-JAN-2020       3.0        0.0    0.0
# 5   27-JAN-2020       3.0        0.0    0.0
# 6   28-JAN-2020       4.0        0.0    0.0
# 7   29-JAN-2020       5.0        0.0    0.0
# 8   30-JAN-2020       5.0        0.0    0.0
# 9   31-JAN-2020       5.0        0.0    0.0
# 10  01-FEB-2020       6.0        0.0    0.0
# 11  02-FEB-2020       6.0        0.0    0.0
# 12  03-FEB-2020       6.0        0.0    0.0
# 13  04-FEB-2020       6.0        0.0    0.0
# 14  05-FEB-2020       6.0        0.0    0.0
# 15  06-FEB-2020       6.0        0.0    0.0
# 16  07-FEB-2020       6.0        0.0    0.0
# 17  08-FEB-2020      11.0        0.0    0.0
# 18  09-FEB-2020      11.0        0.0    0.0
# 19  10-FEB-2020      11.0        0.0    0.0
# 20  11-FEB-2020      11.0        0.0    0.0
# 21  12-FEB-2020      11.0        2.0    0.0
# 22  13-FEB-2020      11.0        2.0    0.0
# 23  14-FEB-2020      11.0        2.0    0.0
# 24  15-FEB-2020      12.0        4.0    1.0
# 25  16-FEB-2020      12.0        4.0    1.0
# 26  17-FEB-2020      12.0        4.0    1.0
# 27  18-FEB-2020      12.0        4.0    1.0
# 28  19-FEB-2020      12.0        4.0    1.0
# 29  20-FEB-2020      12.0        4.0    1.0
# 30  21-FEB-2020      12.0        4.0    1.0
# 31  22-FEB-2020      12.0        4.0    1.0
# 32  23-FEB-2020      12.0        4.0    1.0
# 33  24-FEB-2020      12.0        4.0    1.0
# 34  25-FEB-2020      14.0       11.0    1.0
# 35  26-FEB-2020      18.0       11.0    2.0
# 36  27-FEB-2020      38.0       11.0    2.0
# 37  28-FEB-2020      57.0       11.0    2.0
# 38  29-FEB-2020     100.0       12.0    2.0
# 39  01-MAR-2020     130.0       12.0    2.0
# 40  02-MAR-2020     191.0       12.0    3.0
# 41  03-MAR-2020     204.0       12.0    4.0
# 42  04-MAR-2020     288.0       12.0    4.0
# 43  05-MAR-2020     380.0       12.0    6.0
# 44  06-MAR-2020     656.0       12.0    9.0
# 45  07-MAR-2020     957.0       12.0   11.0
# 46  08-MAR-2020    1134.0       12.0   19.0
# 47  09-MAR-2020    1217.0       12.0   19.0
# 48  10-MAR-2020    1792.0       12.0   33.0
# 49  11-MAR-2020    2289.0       12.0   48.0
# 50  12-MAR-2020    2289.0       12.0   48.0
# 51  13-MAR-2020    3672.0       12.0   79.0
# 52  14-MAR-2020    4480.0       12.0   91.0
# 53  15-MAR-2020    4513.0       12.0   91.0
# 54  16-MAR-2020    6650.0       12.0  148.0
# 55   7-MAR-2020    7699.0       12.0  148.0
# 56  18-MAR-2020    9105.0       12.0  148.0
# 57  19-MAR-2020   10947.0       12.0  243.0

# %%
infected_observed = sheets[chosen_country]['infected'][start_count_day:]

removed_observed = sheets[chosen_country]['recovered'][start_count_day:] + sheets[chosen_country]['death'][start_count_day:]

# %%
len(removed_observed)
# Out:
# 37

# %% [markdown]
# ## Iteratible SIR Model

# %%
t_start = 0.0
t_end = len(removed_observed) + 1       # Transmit Time

N = population
R0 = removed_initial
I0 = infected_initial      # Initial Number of Infectious
S0 = N - I0 - R0    # Initial Number of Susceptible

INPUT = (S0, I0, R0)

def model_SIR(INP,t):  
    Y = np.zeros((3))
    V = INP
    Y[0] = - beta * V[0] * V[1]/N                    # Y[0] is dS(t)/dt, V[0] is S(t)
    Y[1] = beta * V[0] * V[1]/N - gamma * V[1]       # Y[1] is dI(t)/dt, V[1] is I(t)
    Y[2] = gamma * V[1]                            # Y[2] is dR(t)/dt.
    return Y   # For odeint

t_range = np.arange(t_start, t_end)

# %% [markdown]
# ### Start Interation

# %%
start = time.time()

minimum_infected = math.pow(10,10)
minimum_removed = math.pow(10,10)

for gamma in np.arange(0.01, 5.0, 0.001):
    for beta in np.arange(0.01, 5.0, 0.001):
        RES = spi.odeint(model_SIR, INPUT, t_range) 
        
        # Goodness Test of Fitness
        
        #print(RES)
        
        fitness_infected = stats.chisquare(infected_observed, RES[1:, 1])
        fitness_removed = stats.chisquare(removed_observed, RES[1:, 2])
        
       
        if abs(fitness_infected[0]) < 10000 and abs(fitness_removed[0]) < 10000:
            print('\nbeta=', beta, '  gamma=', gamma, fitness_infected, fitness_removed)
        
        
        #print('beta=', beta, '  gamma=', gamma, fitness_infected, fitness_removed)
            
        if abs(fitness_infected[0]) < minimum_infected and abs(fitness_removed[0]) < minimum_removed:
            minimum_infected = fitness_infected[0]
            minimum_removed = fitness_removed[0]
            beta_mini = beta
            gamma_mini = gamma
            
end = time.time()
duration = end - start
            
print('\nThe minimum_infected Z is ', minimum_infected)
print('The minimum_removed Z is ', minimum_removed)
print('when beta is ', beta_mini)
print('when gamma is ', gamma_mini)

print('Time: ', duration)
# Out:
# beta= 0.18499999999999986   gamma= 0.01 Power_divergenceResult(statistic=9712.595321816101, pvalue=0.0) Power_divergenceResult(statistic=505.02004969431346, pvalue=4.5091534762219665e-84)
#
# beta= 0.18599999999999986   gamma= 0.01 Power_divergenceResult(statistic=8391.902160755346, pvalue=0.0) Power_divergenceResult(statistic=550.8488638073853, pvalue=2.1939243157402728e-93)
#
# beta= 0.18699999999999986   gamma= 0.01 Power_divergenceResult(statistic=7211.19593927982, pvalue=0.0) Power_divergenceResult(statistic=599.1590324711769, pvalue=2.945685137643812e-103)
#
# beta= 0.18799999999999986   gamma= 0.01 Power_divergenceResult(statistic=6169.001092229592, pvalue=0.0) Power_divergenceResult(statistic=649.9961581339063, pvalue=1.069764318673072e-113)
#
# beta= 0.18899999999999986   gamma= 0.01 Power_divergenceResult(statistic=5264.00325038904, pvalue=0.0) Power_divergenceResult(statistic=703.407950215987, pvalue=1.0287277549372893e-124)
#
# beta= 0.18999999999999986   gamma= 0.01 Power_divergenceResult(statistic=4495.047597192803, pvalue=0.0) Power_divergenceResult(statistic=759.444277886208, pvalue=2.561288882239381e-136)
#
# beta= 0.19099999999999986   gamma= 0.01 Power_divergenceResult(statistic=3861.1374098411943, pvalue=0.0) Power_divergenceResult(statistic=818.1572254779414, pvalue=1.612309173224544e-148)
#
# beta= 0.19199999999999987   gamma= 0.01 Power_divergenceResult(statistic=3361.4327946844764, pvalue=0.0) Power_divergenceResult(statistic=879.6011499952601, pvalue=2.5026275984509797e-161)
#
# beta= 0.19299999999999987   gamma= 0.01 Power_divergenceResult(statistic=2995.2496309240346, pvalue=0.0) Power_divergenceResult(statistic=943.8327390131776, pvalue=9.329534375460303e-175)
#
# beta= 0.19399999999999984   gamma= 0.01 Power_divergenceResult(statistic=2762.0586885427783, pvalue=0.0) Power_divergenceResult(statistic=1010.911071272041, pvalue=8.124916218964646e-189)
#
# beta= 0.19499999999999984   gamma= 0.01 Power_divergenceResult(statistic=2661.484919968059, pvalue=0.0) Power_divergenceResult(statistic=1080.8976797668527, pvalue=1.6056988365315826e-203)
#
# beta= 0.19599999999999984   gamma= 0.01 Power_divergenceResult(statistic=2693.306945051246, pvalue=0.0) Power_divergenceResult(statistic=1153.8566182093346, pvalue=6.985343945670581e-219)
#
# beta= 0.19699999999999984   gamma= 0.01 Power_divergenceResult(statistic=2857.4567236654552, pvalue=0.0) Power_divergenceResult(statistic=1229.8545276904385, pvalue=6.479963575375076e-235)
#
# beta= 0.19799999999999984   gamma= 0.01 Power_divergenceResult(statistic=3154.0194062165774, pvalue=0.0) Power_divergenceResult(statistic=1308.9607061361196, pvalue=1.2398803311430958e-251)
#
# beta= 0.19899999999999984   gamma= 0.01 Power_divergenceResult(statistic=3583.2333670133576, pvalue=0.0) Power_divergenceResult(statistic=1391.2471805031403, pvalue=4.72647373712966e-269)
#
# beta= 0.19999999999999984   gamma= 0.01 Power_divergenceResult(statistic=4145.490419394949, pvalue=0.0) Power_divergenceResult(statistic=1476.7887827941336, pvalue=3.4619909765211024e-287)
#
# beta= 0.20099999999999985   gamma= 0.01 Power_divergenceResult(statistic=4841.33621993524, pvalue=0.0) Power_divergenceResult(statistic=1565.6632272169595, pvalue=4.692086327337703e-306)
#
# beta= 0.20199999999999985   gamma= 0.01 Power_divergenceResult(statistic=5671.470847288184, pvalue=0.0) Power_divergenceResult(statistic=1657.951189665028, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.01 Power_divergenceResult(statistic=6636.7495648996, pvalue=0.0) Power_divergenceResult(statistic=1753.7363902910893, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.01 Power_divergenceResult(statistic=7738.183779835731, pvalue=0.0) Power_divergenceResult(statistic=1853.105680354319, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.01 Power_divergenceResult(statistic=8976.942181372426, pvalue=0.0) Power_divergenceResult(statistic=1956.149131229594, pvalue=0.0)
#
# beta= 0.18599999999999986   gamma= 0.011 Power_divergenceResult(statistic=9712.633990809012, pvalue=0.0) Power_divergenceResult(statistic=677.7073621228284, pvalue=2.0851537530260157e-119)
#
# beta= 0.18699999999999986   gamma= 0.011 Power_divergenceResult(statistic=8391.938302407769, pvalue=0.0) Power_divergenceResult(statistic=732.1457687206849, pvalue=1.1661048285331735e-130)
#
# beta= 0.18799999999999986   gamma= 0.011 Power_divergenceResult(statistic=7211.2294167434975, pvalue=0.0) Power_divergenceResult(statistic=789.2133759256694, pvalue=1.6876918748728456e-142)
#
# beta= 0.18899999999999986   gamma= 0.011 Power_divergenceResult(statistic=6169.031759079213, pvalue=0.0) Power_divergenceResult(statistic=848.9627489291319, pvalue=6.170443563607718e-155)
#
# beta= 0.18999999999999986   gamma= 0.011 Power_divergenceResult(statistic=5264.030949973486, pvalue=0.0) Power_divergenceResult(statistic=911.448719731315, pvalue=5.556063315937747e-168)
#
# beta= 0.19099999999999986   gamma= 0.011 Power_divergenceResult(statistic=4495.072161940896, pvalue=0.0) Power_divergenceResult(statistic=976.7284459249945, pvalue=1.1996200705668602e-181)
#
# beta= 0.19199999999999987   gamma= 0.011 Power_divergenceResult(statistic=3861.1586605234334, pvalue=0.0) Power_divergenceResult(statistic=1044.8614724432932, pvalue=6.039098239919179e-196)
#
# beta= 0.19299999999999987   gamma= 0.011 Power_divergenceResult(statistic=3361.4505396262357, pvalue=0.0) Power_divergenceResult(statistic=1115.9097955808259, pvalue=6.88328464014527e-211)
#
# beta= 0.19399999999999984   gamma= 0.011 Power_divergenceResult(statistic=2995.26366515668, pvalue=0.0) Power_divergenceResult(statistic=1189.9379274035587, pvalue=1.7225217422995425e-226)
#
# beta= 0.19499999999999984   gamma= 0.011 Power_divergenceResult(statistic=2762.0687928992415, pvalue=0.0) Power_divergenceResult(statistic=1267.0129631420868, pvalue=9.164829902336445e-243)
#
# beta= 0.19599999999999984   gamma= 0.011 Power_divergenceResult(statistic=2661.4908601183615, pvalue=0.0) Power_divergenceResult(statistic=1347.2046513698251, pvalue=1.002543804926581e-259)
#
# beta= 0.19699999999999984   gamma= 0.011 Power_divergenceResult(statistic=2693.308470470684, pvalue=0.0) Power_divergenceResult(statistic=1430.5854679091372, pvalue=2.1772094223566473e-277)
#
# beta= 0.19799999999999984   gamma= 0.011 Power_divergenceResult(statistic=2857.4535665301455, pvalue=0.0) Power_divergenceResult(statistic=1517.2306898767931, pvalue=9.050455014514526e-296)
#
# beta= 0.19899999999999984   gamma= 0.011 Power_divergenceResult(statistic=3154.0112802229473, pvalue=0.0) Power_divergenceResult(statistic=1607.2184728490574, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.011 Power_divergenceResult(statistic=3583.2199661182212, pvalue=0.0) Power_divergenceResult(statistic=1700.629931021559, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.011 Power_divergenceResult(statistic=4145.471416464722, pvalue=0.0) Power_divergenceResult(statistic=1797.549221635547, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.011 Power_divergenceResult(statistic=4841.311265304578, pvalue=0.0) Power_divergenceResult(statistic=1898.063630567156, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.011 Power_divergenceResult(statistic=5671.439567218216, pvalue=0.0) Power_divergenceResult(statistic=2002.26366050837, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.011 Power_divergenceResult(statistic=6636.711559933153, pvalue=0.0) Power_divergenceResult(statistic=2110.2431225363894, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.011 Power_divergenceResult(statistic=7738.138623031045, pvalue=0.0) Power_divergenceResult(statistic=2222.0992324115327, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.011 Power_divergenceResult(statistic=8976.889416416423, pvalue=0.0) Power_divergenceResult(statistic=2337.9327092188073, pvalue=0.0)
#
# beta= 0.18699999999999986   gamma= 0.011999999999999999 Power_divergenceResult(statistic=9712.672866813833, pvalue=0.0) Power_divergenceResult(statistic=862.9931244184099, pvalue=7.317858164236923e-158)
#
# beta= 0.18799999999999986   gamma= 0.011999999999999999 Power_divergenceResult(statistic=8391.97463656892, pvalue=0.0) Power_divergenceResult(statistic=925.7369830055577, pvalue=5.710750173702271e-171)
#
# beta= 0.18899999999999986   gamma= 0.011999999999999999 Power_divergenceResult(statistic=7211.263071638399, pvalue=0.0) Power_divergenceResult(statistic=991.2653558869314, pvalue=1.0745799999259929e-184)
#
# beta= 0.18999999999999986   gamma= 0.011999999999999999 Power_divergenceResult(statistic=6169.062587664771, pvalue=0.0) Power_divergenceResult(statistic=1059.6376001686792, pvalue=4.740791614295642e-199)
#
# beta= 0.19099999999999986   gamma= 0.011999999999999999 Power_divergenceResult(statistic=5264.0587949365045, pvalue=0.0) Power_divergenceResult(statistic=1130.9155027553736, pvalue=4.7619583701796756e-214)
#
# beta= 0.19199999999999987   gamma= 0.011999999999999999 Power_divergenceResult(statistic=4495.096855001622, pvalue=0.0) Power_divergenceResult(statistic=1205.16334512223, pvalue=1.0561212921262934e-229)
#
# beta= 0.19299999999999987   gamma= 0.011999999999999999 Power_divergenceResult(statistic=3861.180021695439, pvalue=0.0) Power_divergenceResult(statistic=1282.4479713688697, pvalue=5.008517172059149e-246)
#
# beta= 0.19399999999999984   gamma= 0.011999999999999999 Power_divergenceResult(statistic=3361.468376423932, pvalue=0.0) Power_divergenceResult(statistic=1362.838858730816, pvalue=4.911743487066501e-263)
#
# beta= 0.19499999999999984   gamma= 0.011999999999999999 Power_divergenceResult(statistic=2995.277771745302, pvalue=0.0) Power_divergenceResult(statistic=1446.4081884754971, pvalue=9.619108997513785e-281)
#
# beta= 0.19599999999999984   gamma= 0.011999999999999999 Power_divergenceResult(statistic=2762.078949186205, pvalue=0.0) Power_divergenceResult(statistic=1533.230920068599, pvalue=3.627539340454173e-299)
#
# beta= 0.19699999999999984   gamma= 0.011999999999999999 Power_divergenceResult(statistic=2661.4968307849394, pvalue=0.0) Power_divergenceResult(statistic=1623.3848684103095, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.011999999999999999 Power_divergenceResult(statistic=2693.310003936549, pvalue=0.0) Power_divergenceResult(statistic=1716.9507851515111, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.011999999999999999 Power_divergenceResult(statistic=2857.4503938443386, pvalue=0.0) Power_divergenceResult(statistic=1814.012440094075, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.011999999999999999 Power_divergenceResult(statistic=3154.003113879494, pvalue=0.0) Power_divergenceResult(statistic=1914.6567060320256, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.011999999999999999 Power_divergenceResult(statistic=3583.206498789871, pvalue=0.0) Power_divergenceResult(statistic=2018.9736468413103, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.011999999999999999 Power_divergenceResult(statistic=4145.452319649982, pvalue=0.0) Power_divergenceResult(statistic=2127.0566102790162, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.011999999999999999 Power_divergenceResult(statistic=4841.2861878782005, pvalue=0.0) Power_divergenceResult(statistic=2239.002321967983, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.011999999999999999 Power_divergenceResult(statistic=5671.408133885215, pvalue=0.0) Power_divergenceResult(statistic=2354.910982242197, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.011999999999999999 Power_divergenceResult(statistic=6636.673369575954, pvalue=0.0) Power_divergenceResult(statistic=2474.8863666739035, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.011999999999999999 Power_divergenceResult(statistic=7738.09324693708, pvalue=0.0) Power_divergenceResult(statistic=2599.0359317821103, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.011999999999999999 Power_divergenceResult(statistic=8976.836396389079, pvalue=0.0) Power_divergenceResult(statistic=2727.470923268266, pvalue=0.0)
# beta= 0.18799999999999986   gamma= 0.012999999999999998 Power_divergenceResult(statistic=9712.711949830213, pvalue=0.0) Power_divergenceResult(statistic=1058.0481841396718, pvalue=1.0231214048742262e-198)
#
# beta= 0.18899999999999986   gamma= 0.012999999999999998 Power_divergenceResult(statistic=8392.011163242363, pvalue=0.0) Power_divergenceResult(statistic=1128.8618475427577, pvalue=1.289247800777119e-213)
#
# beta= 0.18999999999999986   gamma= 0.012999999999999998 Power_divergenceResult(statistic=7211.296903965664, pvalue=0.0) Power_divergenceResult(statistic=1202.6211422052675, pvalue=3.632305368770699e-229)
#
# beta= 0.19099999999999986   gamma= 0.012999999999999998 Power_divergenceResult(statistic=6169.093577986718, pvalue=0.0) Power_divergenceResult(statistic=1279.3920832579543, pvalue=2.216671654339259e-245)
#
# beta= 0.19199999999999987   gamma= 0.012999999999999998 Power_divergenceResult(statistic=5264.086785279511, pvalue=0.0) Power_divergenceResult(statistic=1359.2432811544425, pvalue=2.834852116938803e-262)
#
# beta= 0.19299999999999987   gamma= 0.012999999999999998 Power_divergenceResult(statistic=4495.121676376871, pvalue=0.0) Power_divergenceResult(statistic=1442.2460124123143, pvalue=7.339966119741119e-280)
#
# beta= 0.19399999999999984   gamma= 0.012999999999999998 Power_divergenceResult(statistic=3861.2014933586916, pvalue=0.0) Power_divergenceResult(statistic=1528.474293948053, pvalue=3.7118518210284514e-298)
#
# beta= 0.19499999999999984   gamma= 0.012999999999999998 Power_divergenceResult(statistic=3361.4863050798817, pvalue=0.0) Power_divergenceResult(statistic=1618.0049600553837, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.012999999999999998 Power_divergenceResult(statistic=2995.2919506921908, pvalue=0.0) Power_divergenceResult(statistic=1710.9177397660837, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.012999999999999998 Power_divergenceResult(statistic=2762.0891574059683, pvalue=0.0) Power_divergenceResult(statistic=1807.2953377638971, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.012999999999999998 Power_divergenceResult(statistic=2661.5028319703492, pvalue=0.0) Power_divergenceResult(statistic=1907.223518652108, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.012999999999999998 Power_divergenceResult(statistic=2693.3115454515405, pvalue=0.0) Power_divergenceResult(statistic=2010.791195650097, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.012999999999999998 Power_divergenceResult(statistic=2857.4472056110358, pvalue=0.0) Power_divergenceResult(statistic=2118.090519322586, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=3153.9949071891056, pvalue=0.0) Power_divergenceResult(statistic=2229.2169700678355, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=3583.192965032506, pvalue=0.0) Power_divergenceResult(statistic=2344.2694541086075, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=4145.433128955026, pvalue=0.0) Power_divergenceResult(statistic=2463.3504046299195, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=4841.260987660953, pvalue=0.0) Power_divergenceResult(statistic=2586.565884131407, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=5671.376547292413, pvalue=0.0) Power_divergenceResult(statistic=2714.025689904556, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=6636.634993830591, pvalue=0.0) Power_divergenceResult(statistic=2845.84346348731, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=7738.047651559462, pvalue=0.0) Power_divergenceResult(statistic=2982.136805748369, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.012999999999999998 Power_divergenceResult(statistic=8976.783121295446, pvalue=0.0) Power_divergenceResult(statistic=3123.0273946842717, pvalue=0.0)
#
# beta= 0.18899999999999986   gamma= 0.013999999999999997 Power_divergenceResult(statistic=9712.75123986134, pvalue=0.0) Power_divergenceResult(statistic=1260.8346815890598, pvalue=1.8522098544440364e-241)
#
# beta= 0.18999999999999986   gamma= 0.013999999999999997 Power_divergenceResult(statistic=8392.047882426916, pvalue=0.0) Power_divergenceResult(statistic=1339.531834781036, pvalue=4.218222058688997e-258)
#
# beta= 0.19099999999999986   gamma= 0.013999999999999997 Power_divergenceResult(statistic=7211.330913727325, pvalue=0.0) Power_divergenceResult(statistic=1421.3403358973246, pvalue=1.984523796699729e-275)
#
# beta= 0.19199999999999987   gamma= 0.013999999999999997 Power_divergenceResult(statistic=6169.124730048345, pvalue=0.0) Power_divergenceResult(statistic=1506.3327512135334, pvalue=1.8619913422972987e-293)
#
# beta= 0.19299999999999987   gamma= 0.013999999999999997 Power_divergenceResult(statistic=5264.11492100414, pvalue=0.0) Power_divergenceResult(statistic=1594.5844099175506, pvalue=0.0)
#
# beta= 0.19399999999999984   gamma= 0.013999999999999997 Power_divergenceResult(statistic=4495.146626068211, pvalue=0.0) Power_divergenceResult(statistic=1686.1734808004926, pvalue=0.0)
#
# beta= 0.19499999999999984   gamma= 0.013999999999999997 Power_divergenceResult(statistic=3861.2230755155697, pvalue=0.0) Power_divergenceResult(statistic=1781.1810528511483, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.013999999999999997 Power_divergenceResult(statistic=3361.504325595331, pvalue=0.0) Power_divergenceResult(statistic=1879.6912186799682, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.013999999999999997 Power_divergenceResult(statistic=2995.306201999446, pvalue=0.0) Power_divergenceResult(statistic=1981.791158322591, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.013999999999999997 Power_divergenceResult(statistic=2762.099417560921, pvalue=0.0) Power_divergenceResult(statistic=2087.571226882077, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.013999999999999997 Power_divergenceResult(statistic=2661.5088636771206, pvalue=0.0) Power_divergenceResult(statistic=2197.1250458012296, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.013999999999999997 Power_divergenceResult(statistic=2693.3130950185, pvalue=0.0) Power_divergenceResult(statistic=2310.5495989148158, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=2857.4440018335135, pvalue=0.0) Power_divergenceResult(statistic=2427.945328484613, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=3153.9866601555605, pvalue=0.0) Power_divergenceResult(statistic=2549.416235309561, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=3583.179364849803, pvalue=0.0) Power_divergenceResult(statistic=2675.06998259305, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=4145.413844384126, pvalue=0.0) Power_divergenceResult(statistic=2805.018005390314, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=4841.235664655708, pvalue=0.0) Power_divergenceResult(statistic=2939.375621303585, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=5671.34480744592, pvalue=0.0) Power_divergenceResult(statistic=3078.262144566046, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=6636.596432704338, pvalue=0.0) Power_divergenceResult(statistic=3221.8010043942413, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=7738.001836904662, pvalue=0.0) Power_divergenceResult(statistic=3370.119869422609, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.013999999999999997 Power_divergenceResult(statistic=8976.729591140125, pvalue=0.0) Power_divergenceResult(statistic=3523.350775032788, pvalue=0.0)
#
# beta= 0.18999999999999986   gamma= 0.014999999999999996 Power_divergenceResult(statistic=9712.79073690699, pvalue=0.0) Power_divergenceResult(statistic=1469.8468943938367, pvalue=1.0280143736254596e-285)
#
# beta= 0.19099999999999986   gamma= 0.014999999999999996 Power_divergenceResult(statistic=8392.084794125418, pvalue=0.0) Power_divergenceResult(statistic=1556.2776622712017, pvalue=4.624682988594297e-304)
#
# beta= 0.19199999999999987   gamma= 0.014999999999999996 Power_divergenceResult(statistic=7211.365100925001, pvalue=0.0) Power_divergenceResult(statistic=1645.9892024097858, pvalue=0.0)
#
# beta= 0.19299999999999987   gamma= 0.014999999999999996 Power_divergenceResult(statistic=6169.156043849684, pvalue=0.0) Power_divergenceResult(statistic=1739.0605455539157, pvalue=0.0)
#
# beta= 0.19399999999999984   gamma= 0.014999999999999996 Power_divergenceResult(statistic=5264.143202111794, pvalue=0.0) Power_divergenceResult(statistic=1835.5736546524768, pvalue=0.0)
#
# beta= 0.19499999999999984   gamma= 0.014999999999999996 Power_divergenceResult(statistic=4495.171704078143, pvalue=0.0) Power_divergenceResult(statistic=1935.6135074830072, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.014999999999999996 Power_divergenceResult(statistic=3861.2447681671806, pvalue=0.0) Power_divergenceResult(statistic=2039.2681834857049, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.014999999999999996 Power_divergenceResult(statistic=3361.5224379728415, pvalue=0.0) Power_divergenceResult(statistic=2146.628953612102, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.014999999999999996 Power_divergenceResult(statistic=2995.32052566904, pvalue=0.0) Power_divergenceResult(statistic=2257.7903705555627, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.014999999999999996 Power_divergenceResult(statistic=2762.1097296534276, pvalue=0.0) Power_divergenceResult(statistic=2372.8503630998935, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.014999999999999996 Power_divergenceResult(statistic=2661.5149259078757, pvalue=0.0) Power_divergenceResult(statistic=2491.9103343768948, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=2693.314652640124, pvalue=0.0) Power_divergenceResult(statistic=2615.0752652503834, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=2857.4407825143626, pvalue=0.0) Power_divergenceResult(statistic=2742.453817638423, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=3153.9783727820145, pvalue=0.0) Power_divergenceResult(statistic=2874.158442222631, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=3583.165698245132, pvalue=0.0) Power_divergenceResult(statistic=3010.305490169989, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=4145.394465939775, pvalue=0.0) Power_divergenceResult(statistic=3151.015330866194, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=4841.210218867519, pvalue=0.0) Power_divergenceResult(statistic=3296.4124709326247, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=5671.312914348522, pvalue=0.0) Power_divergenceResult(statistic=3446.625676892296, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=6636.557686201073, pvalue=0.0) Power_divergenceResult(statistic=3601.7881024000026, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=7737.9558029756945, pvalue=0.0) Power_divergenceResult(statistic=3762.037422000456, pvalue=0.0)
#
# beta= 0.20999999999999985   gamma= 0.014999999999999996 Power_divergenceResult(statistic=8976.675805930821, pvalue=0.0) Power_divergenceResult(statistic=3927.515967969077, pvalue=0.0)
# beta= 0.19099999999999986   gamma= 0.015999999999999993 Power_divergenceResult(statistic=9712.830440969905, pvalue=0.0) Power_divergenceResult(statistic=1683.947808276492, pvalue=0.0)
#
# beta= 0.19199999999999987   gamma= 0.015999999999999993 Power_divergenceResult(statistic=8392.121898338175, pvalue=0.0) Power_divergenceResult(statistic=1777.989820643786, pvalue=0.0)
#
# beta= 0.19299999999999987   gamma= 0.015999999999999993 Power_divergenceResult(statistic=7211.399465558537, pvalue=0.0) Power_divergenceResult(statistic=1875.485062064941, pvalue=0.0)
#
# beta= 0.19399999999999984   gamma= 0.015999999999999993 Power_divergenceResult(statistic=6169.187519392878, pvalue=0.0) Power_divergenceResult(statistic=1976.51895648977, pvalue=0.0)
#
# beta= 0.19499999999999984   gamma= 0.015999999999999993 Power_divergenceResult(statistic=5264.171628604842, pvalue=0.0) Power_divergenceResult(statistic=2081.1800307855565, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.015999999999999993 Power_divergenceResult(statistic=4495.1969104083055, pvalue=0.0) Power_divergenceResult(statistic=2189.5600032776442, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.015999999999999993 Power_divergenceResult(statistic=3861.2665713166584, pvalue=0.0) Power_divergenceResult(statistic=2301.7538768056015, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.015999999999999993 Power_divergenceResult(statistic=3361.540642214621, pvalue=0.0) Power_divergenceResult(statistic=2417.860034979531, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.015999999999999993 Power_divergenceResult(statistic=2995.334921703664, pvalue=0.0) Power_divergenceResult(statistic=2537.9803388202226, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.015999999999999993 Power_divergenceResult(statistic=2762.1200936859354, pvalue=0.0) Power_divergenceResult(statistic=2662.2202277984225, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=2661.5210186652275, pvalue=0.0) Power_divergenceResult(statistic=2790.6888250572224, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=2693.316218319326, pvalue=0.0) Power_divergenceResult(statistic=2923.499048110036, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=2857.4375476568894, pvalue=0.0) Power_divergenceResult(statistic=3060.767719430635, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=3153.970045071158, pvalue=0.0) Power_divergenceResult(statistic=3202.6156817444203, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=3583.151965221409, pvalue=0.0) Power_divergenceResult(statistic=3349.167917585222, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=4145.374993626705, pvalue=0.0) Power_divergenceResult(statistic=3500.553675293533, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=4841.18465030079, pvalue=0.0) Power_divergenceResult(statistic=3656.906596336697, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=5671.280868005578, pvalue=0.0) Power_divergenceResult(statistic=3818.364846537991, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=6636.51875432548, pvalue=0.0) Power_divergenceResult(statistic=3985.0712521648866, pvalue=0.0)
#
# beta= 0.20999999999999985   gamma= 0.015999999999999993 Power_divergenceResult(statistic=7737.909549778594, pvalue=0.0) Power_divergenceResult(statistic=4157.173442989802, pvalue=0.0)
#
# beta= 0.21099999999999983   gamma= 0.015999999999999993 Power_divergenceResult(statistic=8976.621765672147, pvalue=0.0) Power_divergenceResult(statistic=4334.823998623097, pvalue=0.0)
#
# beta= 0.19199999999999987   gamma= 0.016999999999999994 Power_divergenceResult(statistic=9712.870352049453, pvalue=0.0) Power_divergenceResult(statistic=1902.2625160281484, pvalue=0.0)
#
# beta= 0.19299999999999987   gamma= 0.016999999999999994 Power_divergenceResult(statistic=8392.15919506766, pvalue=0.0) Power_divergenceResult(statistic=2003.814555525555, pvalue=0.0)
#
# beta= 0.19399999999999984   gamma= 0.016999999999999994 Power_divergenceResult(statistic=7211.434007632392, pvalue=0.0) Power_divergenceResult(statistic=2108.994792784799, pvalue=0.0)
#
# beta= 0.19499999999999984   gamma= 0.016999999999999994 Power_divergenceResult(statistic=6169.219156679762, pvalue=0.0) Power_divergenceResult(statistic=2217.894985660596, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.016999999999999994 Power_divergenceResult(statistic=5264.200200484867, pvalue=0.0) Power_divergenceResult(statistic=2330.610166833014, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.016999999999999994 Power_divergenceResult(statistic=4495.222245059574, pvalue=0.0) Power_divergenceResult(statistic=2447.238738252373, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.016999999999999994 Power_divergenceResult(statistic=3861.2884849647485, pvalue=0.0) Power_divergenceResult(statistic=2567.8825703995785, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.016999999999999994 Power_divergenceResult(statistic=3361.5589383228144, pvalue=0.0) Power_divergenceResult(statistic=2692.647104936214, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.016999999999999994 Power_divergenceResult(statistic=2995.349390105288, pvalue=0.0) Power_divergenceResult(statistic=2821.6414577398973, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=2762.1305096610213, pvalue=0.0) Power_divergenceResult(statistic=2954.9785266168815, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=2661.5271419517967, pvalue=0.0) Power_divergenceResult(statistic=3092.775103476409, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=2693.3177920587686, pvalue=0.0) Power_divergenceResult(statistic=3235.151992320768, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=2857.4342972642785, pvalue=0.0) Power_divergenceResult(statistic=3382.234127093267, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=3153.9616770270495, pvalue=0.0) Power_divergenceResult(statistic=3534.150694530189, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=3583.138165783319, pvalue=0.0) Power_divergenceResult(statistic=3691.03526153948, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=4145.355427448942, pvalue=0.0) Power_divergenceResult(statistic=3853.0259094438607, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=4841.158958958625, pvalue=0.0) Power_divergenceResult(statistic=4020.2653695894933, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=5671.248668421133, pvalue=0.0) Power_divergenceResult(statistic=4192.901163121201, pvalue=0.0)
#
# beta= 0.20999999999999985   gamma= 0.016999999999999994 Power_divergenceResult(statistic=6636.479637082337, pvalue=0.0) Power_divergenceResult(statistic=4371.085745910871, pvalue=0.0)
#
# beta= 0.21099999999999983   gamma= 0.016999999999999994 Power_divergenceResult(statistic=7737.863077320246, pvalue=0.0) Power_divergenceResult(statistic=4554.976660904814, pvalue=0.0)
#
# beta= 0.21199999999999983   gamma= 0.016999999999999994 Power_divergenceResult(statistic=8976.567470370885, pvalue=0.0) Power_divergenceResult(statistic=4744.7366939302065, pvalue=0.0)
#
# beta= 0.19299999999999987   gamma= 0.017999999999999995 Power_divergenceResult(statistic=9712.910470147566, pvalue=0.0) Power_divergenceResult(statistic=2124.1066318178337, pvalue=0.0)
#
# beta= 0.19399999999999984   gamma= 0.017999999999999995 Power_divergenceResult(statistic=8392.196684314911, pvalue=0.0) Power_divergenceResult(statistic=2233.0840171486516, pvalue=0.0)
#
# beta= 0.19499999999999984   gamma= 0.017999999999999995 Power_divergenceResult(statistic=7211.468727145209, pvalue=0.0) Power_divergenceResult(statistic=2345.866673083187, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.017999999999999995 Power_divergenceResult(statistic=6169.250955711261, pvalue=0.0) Power_divergenceResult(statistic=2462.5526415051045, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.017999999999999995 Power_divergenceResult(statistic=5264.22891775261, pvalue=0.0) Power_divergenceResult(statistic=2583.2434120481907, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.017999999999999995 Power_divergenceResult(statistic=4495.247708034707, pvalue=0.0) Power_divergenceResult(statistic=2708.0440224311833, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.017999999999999995 Power_divergenceResult(statistic=3861.3105091141097, pvalue=0.0) Power_divergenceResult(statistic=2837.063163909928, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.017999999999999995 Power_divergenceResult(statistic=3361.577326298928, pvalue=0.0) Power_divergenceResult(statistic=2970.413290305961, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=2995.3639308761713, pvalue=0.0) Power_divergenceResult(statistic=3108.2107274244045, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=2762.140977580813, pvalue=0.0) Power_divergenceResult(statistic=3250.575787428024, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=2661.5332957701503, pvalue=0.0) Power_divergenceResult(statistic=3397.6328879461066, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=2693.319373861477, pvalue=0.0) Power_divergenceResult(statistic=3549.5106773456037, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=2857.431031339291, pvalue=0.0) Power_divergenceResult(statistic=3706.3421598192617, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=3153.953268652198, pvalue=0.0) Power_divergenceResult(statistic=3868.2648257870833, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=3583.1242999334054, pvalue=0.0) Power_divergenceResult(statistic=4035.4207870814566, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=4145.335767409999, pvalue=0.0) Power_divergenceResult(statistic=4207.956919419158, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=4841.133144846213, pvalue=0.0) Power_divergenceResult(statistic=4386.025006284871, pvalue=0.0)
#
# beta= 0.20999999999999985   gamma= 0.017999999999999995 Power_divergenceResult(statistic=5671.216315599937, pvalue=0.0) Power_divergenceResult(statistic=4569.781887237954, pvalue=0.0)
#
# beta= 0.21099999999999983   gamma= 0.017999999999999995 Power_divergenceResult(statistic=6636.440334477245, pvalue=0.0) Power_divergenceResult(statistic=4759.38961166702, pvalue=0.0)
#
# beta= 0.21199999999999983   gamma= 0.017999999999999995 Power_divergenceResult(statistic=7737.816385603817, pvalue=0.0) Power_divergenceResult(statistic=4955.015600407028, pvalue=0.0)
#
# beta= 0.21299999999999983   gamma= 0.017999999999999995 Power_divergenceResult(statistic=8976.512920030995, pvalue=0.0) Power_divergenceResult(statistic=5156.83281100672, pvalue=0.0)
# beta= 0.19399999999999984   gamma= 0.018999999999999993 Power_divergenceResult(statistic=9712.950795266679, pvalue=0.0) Power_divergenceResult(statistic=2348.936985859401, pvalue=0.0)
#
# beta= 0.19499999999999984   gamma= 0.018999999999999993 Power_divergenceResult(statistic=8392.234366080085, pvalue=0.0) Power_divergenceResult(statistic=2465.2681505392775, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.018999999999999993 Power_divergenceResult(statistic=7211.503624101173, pvalue=0.0) Power_divergenceResult(statistic=2585.583438794228, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.018999999999999993 Power_divergenceResult(statistic=6169.282916490123, pvalue=0.0) Power_divergenceResult(statistic=2709.9871341893427, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.018999999999999993 Power_divergenceResult(statistic=5264.257780411324, pvalue=0.0) Power_divergenceResult(statistic=2838.587141833385, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.018999999999999993 Power_divergenceResult(statistic=4495.273299335648, pvalue=0.0) Power_divergenceResult(statistic=2971.4950945944443, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.018999999999999993 Power_divergenceResult(statistic=3861.332643766604, pvalue=0.0) Power_divergenceResult(statistic=3108.8264647300985, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=3361.5958061453775, pvalue=0.0) Power_divergenceResult(statistic=3250.7006792828633, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=2995.3785440187553, pvalue=0.0) Power_divergenceResult(statistic=3397.24123586873, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=2762.1514974479155, pvalue=0.0) Power_divergenceResult(statistic=3548.575823701629, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=2661.539480122955, pvalue=0.0) Power_divergenceResult(statistic=3704.836449622746, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=2693.3209637302643, pvalue=0.0) Power_divergenceResult(statistic=3866.159570640265, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=2857.42774988501, pvalue=0.0) Power_divergenceResult(statistic=4032.6862262459435, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=3153.9448199507037, pvalue=0.0) Power_divergenceResult(statistic=4204.562176353657, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=3583.1103676764637, pvalue=0.0) Power_divergenceResult(statistic=4381.938044277264, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=4145.316013513468, pvalue=0.0) Power_divergenceResult(statistic=4564.969467418322, pvalue=0.0)
#
# beta= 0.20999999999999985   gamma= 0.018999999999999993 Power_divergenceResult(statistic=4841.107207967276, pvalue=0.0) Power_divergenceResult(statistic=4753.817249413963, pvalue=0.0)
#
# beta= 0.21099999999999983   gamma= 0.018999999999999993 Power_divergenceResult(statistic=5671.1838095465655, pvalue=0.0) Power_divergenceResult(statistic=4948.647516959526, pvalue=0.0)
#
# beta= 0.21199999999999983   gamma= 0.018999999999999993 Power_divergenceResult(statistic=6636.400846514398, pvalue=0.0) Power_divergenceResult(statistic=5149.631882378618, pvalue=0.0)
#
# beta= 0.21299999999999983   gamma= 0.018999999999999993 Power_divergenceResult(statistic=7737.769474636519, pvalue=0.0) Power_divergenceResult(statistic=5356.947614496292, pvalue=0.0)
#
# beta= 0.21399999999999983   gamma= 0.018999999999999993 Power_divergenceResult(statistic=8976.45811466062, pvalue=0.0) Power_divergenceResult(statistic=5570.777813353738, pvalue=0.0)
#
# beta= 0.19499999999999984   gamma= 0.01999999999999999 Power_divergenceResult(statistic=9712.991327407246, pvalue=0.0) Power_divergenceResult(statistic=2576.316900086314, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.01999999999999999 Power_divergenceResult(statistic=8392.272240366432, pvalue=0.0) Power_divergenceResult(statistic=2699.940813265315, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.01999999999999999 Power_divergenceResult(statistic=7211.538698498409, pvalue=0.0) Power_divergenceResult(statistic=2827.729222419386, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.01999999999999999 Power_divergenceResult(statistic=6169.315039016376, pvalue=0.0) Power_divergenceResult(statistic=2959.792616529335, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.01999999999999999 Power_divergenceResult(statistic=5264.286788461561, pvalue=0.0) Power_divergenceResult(statistic=3096.2452806654305, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.01999999999999999 Power_divergenceResult(statistic=4495.299018963429, pvalue=0.0) Power_divergenceResult(statistic=3237.2054080719454, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=3861.354888924094, pvalue=0.0) Power_divergenceResult(statistic=3382.795217963888, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=3361.6143778646156, pvalue=0.0) Power_divergenceResult(statistic=3533.141077279514, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=2995.3932295352683, pvalue=0.0) Power_divergenceResult(statistic=3688.3736228288153, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=2762.1620692648144, pvalue=0.0) Power_divergenceResult(statistic=3848.627888957023, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=2661.5456950129224, pvalue=0.0) Power_divergenceResult(statistic=4014.043440484399, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=2693.3225616677073, pvalue=0.0) Power_divergenceResult(statistic=4184.764512501223, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=2857.424452904602, pvalue=0.0) Power_divergenceResult(statistic=4360.940149904922, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=3153.9363309254904, pvalue=0.0) Power_divergenceResult(statistic=4542.724352861186, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=3583.0963690146064, pvalue=0.0) Power_divergenceResult(statistic=4730.276227565995, pvalue=0.0)
#
# beta= 0.20999999999999985   gamma= 0.01999999999999999 Power_divergenceResult(statistic=4145.296165763715, pvalue=0.0) Power_divergenceResult(statistic=4923.760145137001, pvalue=0.0)
#
# beta= 0.21099999999999983   gamma= 0.01999999999999999 Power_divergenceResult(statistic=4841.081148326016, pvalue=0.0) Power_divergenceResult(statistic=5123.345902012702, pvalue=0.0)
#
# beta= 0.21199999999999983   gamma= 0.01999999999999999 Power_divergenceResult(statistic=5671.151150266191, pvalue=0.0) Power_divergenceResult(statistic=5329.208885282731, pvalue=0.0)
#
# beta= 0.21299999999999983   gamma= 0.01999999999999999 Power_divergenceResult(statistic=6636.361173199538, pvalue=0.0) Power_divergenceResult(statistic=5541.5302440597825, pvalue=0.0)
#
# beta= 0.21399999999999983   gamma= 0.01999999999999999 Power_divergenceResult(statistic=7737.722344422311, pvalue=0.0) Power_divergenceResult(statistic=5760.497069598834, pvalue=0.0)
#
# beta= 0.21499999999999983   gamma= 0.01999999999999999 Power_divergenceResult(statistic=8976.40305426348, pvalue=0.0) Power_divergenceResult(statistic=5986.302579447476, pvalue=0.0)
#
# beta= 0.19599999999999984   gamma= 0.02099999999999999 Power_divergenceResult(statistic=9713.032066570111, pvalue=0.0) Power_divergenceResult(statistic=2805.891245351565, pvalue=0.0)
#
# beta= 0.19699999999999984   gamma= 0.02099999999999999 Power_divergenceResult(statistic=8392.310307175097, pvalue=0.0) Power_divergenceResult(statistic=2936.7554375078444, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.02099999999999999 Power_divergenceResult(statistic=7211.573950341317, pvalue=0.0) Power_divergenceResult(statistic=3071.9658053195762, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.02099999999999999 Power_divergenceResult(statistic=6169.347323293932, pvalue=0.0) Power_divergenceResult(statistic=3211.6390118887084, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.02099999999999999 Power_divergenceResult(statistic=5264.315941905215, pvalue=0.0) Power_divergenceResult(statistic=3355.8956916051357, pvalue=0.0)
#
# beta= 0.20099999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=4495.324866920363, pvalue=0.0) Power_divergenceResult(statistic=3504.8605680892083, pvalue=0.0)
#
# beta= 0.20199999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=3861.3772445886407, pvalue=0.0) Power_divergenceResult(statistic=3658.6625781474318, pvalue=0.0)
#
# beta= 0.20299999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=3361.633041458315, pvalue=0.0) Power_divergenceResult(statistic=3817.434999870584, pvalue=0.0)
#
# beta= 0.20399999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=2995.407987427824, pvalue=0.0) Power_divergenceResult(statistic=3981.315581133363, pvalue=0.0)
#
# beta= 0.20499999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=2762.172693033948, pvalue=0.0) Power_divergenceResult(statistic=4150.446673887669, pvalue=0.0)
#
# beta= 0.20599999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=2661.551940442551, pvalue=0.0) Power_divergenceResult(statistic=4324.975374002823, pvalue=0.0)
#
# beta= 0.20699999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=2693.324167677297, pvalue=0.0) Power_divergenceResult(statistic=4505.053668306197, pvalue=0.0)
#
# beta= 0.20799999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=2857.4211404011917, pvalue=0.0) Power_divergenceResult(statistic=4690.838581327955, pvalue=0.0)
#
# beta= 0.20899999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=3153.927801580203, pvalue=0.0) Power_divergenceResult(statistic=4882.492328280968, pvalue=0.0)
#
# beta= 0.20999999999999985   gamma= 0.02099999999999999 Power_divergenceResult(statistic=3583.0823039524557, pvalue=0.0) Power_divergenceResult(statistic=5080.182473591729, pvalue=0.0)
#
# beta= 0.21099999999999983   gamma= 0.02099999999999999 Power_divergenceResult(statistic=4145.276224164874, pvalue=0.0) Power_divergenceResult(statistic=5284.082097987577, pvalue=0.0)
#
# beta= 0.21199999999999983   gamma= 0.02099999999999999 Power_divergenceResult(statistic=4841.054965926465, pvalue=0.0) Power_divergenceResult(statistic=5494.369967136553, pvalue=0.0)
#
# beta= 0.21299999999999983   gamma= 0.02099999999999999 Power_divergenceResult(statistic=5671.118337762299, pvalue=0.0) Power_divergenceResult(statistic=5711.230705476684, pvalue=0.0)
#
# beta= 0.21399999999999983   gamma= 0.02099999999999999 Power_divergenceResult(statistic=6636.321314537236, pvalue=0.0) Power_divergenceResult(statistic=5934.854976378575, pvalue=0.0)
#
# beta= 0.21499999999999983   gamma= 0.02099999999999999 Power_divergenceResult(statistic=7737.674994968302, pvalue=0.0) Power_divergenceResult(statistic=6165.439671500848, pvalue=0.0)
#
# beta= 0.21599999999999983   gamma= 0.02099999999999999 Power_divergenceResult(statistic=8976.347738846845, pvalue=0.0) Power_divergenceResult(statistic=6403.188104365965, pvalue=0.0)
# beta= 0.19699999999999984   gamma= 0.021999999999999992 Power_divergenceResult(statistic=9713.073012757919, pvalue=0.0) Power_divergenceResult(statistic=3037.3682063898796, pvalue=0.0)
#
# beta= 0.19799999999999984   gamma= 0.021999999999999992 Power_divergenceResult(statistic=8392.348566506838, pvalue=0.0) Power_divergenceResult(statistic=3175.427237187627, pvalue=0.0)
#
# beta= 0.19899999999999984   gamma= 0.021999999999999992 Power_divergenceResult(statistic=7211.609379630617, pvalue=0.0) Power_divergenceResult(statistic=3318.01525620064, pvalue=0.0)
#
# beta= 0.19999999999999984   gamma= 0.021999999999999992 Power_divergenceResult(statistic=6169.37976932122, pvalue=0.0) Power_divergenceResult(statistic=3465.2550734586407, pvalue=0.0)
#
# ...
#
# beta= 0.21499999999999983   gamma= 0.03699999999999998 Power_divergenceResult(statistic=6169.885871045422, pvalue=0.0) Power_divergenceResult(statistic=7385.963810444422, pvalue=0.0)
#
# beta= 0.21599999999999983   gamma= 0.03699999999999998 Power_divergenceResult(statistic=5264.802171971724, pvalue=0.0) Power_divergenceResult(statistic=7651.652728312645, pvalue=0.0)
#
# beta= 0.21699999999999983   gamma= 0.03699999999999998 Power_divergenceResult(statistic=4495.755888541633, pvalue=0.0) Power_divergenceResult(statistic=7925.34743125076, pvalue=0.0)
#
# beta= 0.21799999999999983   gamma= 0.03699999999999998 Power_divergenceResult(statistic=3861.7499658347024, pvalue=0.0) Power_divergenceResult(statistic=8207.282241619372, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.03699999999999998 Power_divergenceResult(statistic=3361.9441556950505, pvalue=0.0) Power_divergenceResult(statistic=8497.698965126776, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.03699999999999998 Power_divergenceResult(statistic=2995.6539587875877, pvalue=0.0) Power_divergenceResult(statistic=8796.84712022074, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.03699999999999998 Power_divergenceResult(statistic=2762.3497409086062, pvalue=0.0) Power_divergenceResult(statistic=9104.984177691864, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.03699999999999998 Power_divergenceResult(statistic=2661.6560229505626, pvalue=0.0) Power_divergenceResult(statistic=9422.375810124871, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.03699999999999998 Power_divergenceResult(statistic=2693.350963986783, pvalue=0.0) Power_divergenceResult(statistic=9749.29615404283, pvalue=0.0)
# beta= 0.21299999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=9713.756308159926, pvalue=0.0) Power_divergenceResult(statistic=6879.198527084602, pvalue=0.0)
#
# beta= 0.21399999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=8392.986900161575, pvalue=0.0) Power_divergenceResult(statistic=7129.090373545962, pvalue=0.0)
#
# beta= 0.21499999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=7212.200382193008, pvalue=0.0) Power_divergenceResult(statistic=7386.518218633255, pvalue=0.0)
#
# beta= 0.21599999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=6169.920905323956, pvalue=0.0) Power_divergenceResult(statistic=7651.701234670118, pvalue=0.0)
#
# beta= 0.21699999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=5264.833797379241, pvalue=0.0) Power_divergenceResult(statistic=7924.86559563085, pvalue=0.0)
#
# beta= 0.21799999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=4495.783918386204, pvalue=0.0) Power_divergenceResult(statistic=8206.244693877003, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=3861.7742004322463, pvalue=0.0) Power_divergenceResult(statistic=8496.079367891773, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.03799999999999998 Power_divergenceResult(statistic=3361.9643814949436, pvalue=0.0) Power_divergenceResult(statistic=8794.618137410316, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.03799999999999998 Power_divergenceResult(statistic=2995.6699474374236, pvalue=0.0) Power_divergenceResult(statistic=9102.117439088142, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.03799999999999998 Power_divergenceResult(statistic=2762.361248255805, pvalue=0.0) Power_divergenceResult(statistic=9418.841872657596, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.03799999999999998 Power_divergenceResult(statistic=2661.662787976595, pvalue=0.0) Power_divergenceResult(statistic=9745.064457202481, pvalue=0.0)
#
# beta= 0.21399999999999983   gamma= 0.03899999999999998 Power_divergenceResult(statistic=9713.800773968462, pvalue=0.0) Power_divergenceResult(statistic=7124.036259431523, pvalue=0.0)
#
# beta= 0.21499999999999983   gamma= 0.03899999999999998 Power_divergenceResult(statistic=8393.028432612406, pvalue=0.0) Power_divergenceResult(statistic=7380.806023012444, pvalue=0.0)
#
# beta= 0.21599999999999983   gamma= 0.03899999999999998 Power_divergenceResult(statistic=7212.238828305528, pvalue=0.0) Power_divergenceResult(statistic=7645.302511447771, pvalue=0.0)
#
# beta= 0.21699999999999983   gamma= 0.03899999999999998 Power_divergenceResult(statistic=6169.956101383231, pvalue=0.0) Power_divergenceResult(statistic=7917.750851339372, pvalue=0.0)
#
# beta= 0.21799999999999983   gamma= 0.03899999999999998 Power_divergenceResult(statistic=5264.865568212121, pvalue=0.0) Power_divergenceResult(statistic=8198.38335081873, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.03899999999999998 Power_divergenceResult(statistic=4495.812076595004, pvalue=0.0) Power_divergenceResult(statistic=8487.439722064299, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.03899999999999998 Power_divergenceResult(statistic=3861.7985455742523, pvalue=0.0) Power_divergenceResult(statistic=8785.167315112618, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.03899999999999998 Power_divergenceResult(statistic=3361.9846992096845, pvalue=0.0) Power_divergenceResult(statistic=9091.821359252259, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.03899999999999998 Power_divergenceResult(statistic=2995.68600850675, pvalue=0.0) Power_divergenceResult(statistic=9407.665204969839, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.03899999999999998 Power_divergenceResult(statistic=2762.3728076017146, pvalue=0.0) Power_divergenceResult(statistic=9732.970576657686, pvalue=0.0)
#
# beta= 0.21499999999999983   gamma= 0.03999999999999997 Power_divergenceResult(statistic=9713.845446827185, pvalue=0.0) Power_divergenceResult(statistic=7369.184661943054, pvalue=0.0)
#
# beta= 0.21599999999999983   gamma= 0.03999999999999997 Power_divergenceResult(statistic=8393.07015761287, pvalue=0.0) Power_divergenceResult(statistic=7632.825045607209, pvalue=0.0)
#
# beta= 0.21699999999999983   gamma= 0.03999999999999997 Power_divergenceResult(statistic=7212.277451893165, pvalue=0.0) Power_divergenceResult(statistic=7904.383062332988, pvalue=0.0)
#
# beta= 0.21799999999999983   gamma= 0.03999999999999997 Power_divergenceResult(statistic=6169.991459224131, pvalue=0.0) Power_divergenceResult(statistic=8184.08978847754, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.03999999999999997 Power_divergenceResult(statistic=5264.89748447323, pvalue=0.0) Power_divergenceResult(statistic=8472.183661901425, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.03999999999999997 Power_divergenceResult(statistic=4495.840363169467, pvalue=0.0) Power_divergenceResult(statistic=8768.910710268676, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.03999999999999997 Power_divergenceResult(statistic=3861.823001262733, pvalue=0.0) Power_divergenceResult(statistic=9074.524790928475, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.03999999999999997 Power_divergenceResult(statistic=3362.0051088415794, pvalue=0.0) Power_divergenceResult(statistic=9389.287838574412, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.03999999999999997 Power_divergenceResult(statistic=2995.702141998096, pvalue=0.0) Power_divergenceResult(statistic=9713.470113464015, pvalue=0.0)
#
# beta= 0.21599999999999983   gamma= 0.040999999999999974 Power_divergenceResult(statistic=9713.890326736886, pvalue=0.0) Power_divergenceResult(statistic=7614.621511856436, pvalue=0.0)
#
# beta= 0.21699999999999983   gamma= 0.040999999999999974 Power_divergenceResult(statistic=8393.112075165986, pvalue=0.0) Power_divergenceResult(statistic=7885.125745085387, pvalue=0.0)
#
# beta= 0.21799999999999983   gamma= 0.040999999999999974 Power_divergenceResult(statistic=7212.3162529566, pvalue=0.0) Power_divergenceResult(statistic=8163.738688360376, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.040999999999999974 Power_divergenceResult(statistic=6170.026978849124, pvalue=0.0) Power_divergenceResult(statistic=8450.697363588719, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.040999999999999974 Power_divergenceResult(statistic=5264.929546164602, pvalue=0.0) Power_divergenceResult(statistic=8746.246334246782, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.040999999999999974 Power_divergenceResult(statistic=4495.8687781128665, pvalue=0.0) Power_divergenceResult(statistic=9050.637939457742, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.040999999999999974 Power_divergenceResult(statistic=3861.8475675003, pvalue=0.0) Power_divergenceResult(statistic=9364.132539944087, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.040999999999999974 Power_divergenceResult(statistic=3362.0256103933893, pvalue=0.0) Power_divergenceResult(statistic=9686.998771947156, pvalue=0.0)
#
# beta= 0.21699999999999983   gamma= 0.041999999999999975 Power_divergenceResult(statistic=9713.935413697782, pvalue=0.0) Power_divergenceResult(statistic=7860.326664384676, pvalue=0.0)
#
# beta= 0.21799999999999983   gamma= 0.041999999999999975 Power_divergenceResult(statistic=8393.154185271947, pvalue=0.0) Power_divergenceResult(statistic=8137.688453554431, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.041999999999999975 Power_divergenceResult(statistic=7212.355231498998, pvalue=0.0) Power_divergenceResult(statistic=8423.350186569398, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.041999999999999975 Power_divergenceResult(statistic=6170.062660259617, pvalue=0.0) Power_divergenceResult(statistic=8717.554826974452, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.041999999999999975 Power_divergenceResult(statistic=5264.9617532874545, pvalue=0.0) Power_divergenceResult(statistic=9020.553060030987, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.041999999999999975 Power_divergenceResult(statistic=4495.897321425591, pvalue=0.0) Power_divergenceResult(statistic=9332.603532572904, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.041999999999999975 Power_divergenceResult(statistic=3861.8722442888097, pvalue=0.0) Power_divergenceResult(statistic=9653.973105026576, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.041999999999999975 Power_divergenceResult(statistic=3362.046203866735, pvalue=0.0) Power_divergenceResult(statistic=9984.937111591673, pvalue=0.0)
# beta= 0.21799999999999983   gamma= 0.042999999999999976 Power_divergenceResult(statistic=9713.98070771275, pvalue=0.0) Power_divergenceResult(statistic=8106.28181466921, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.042999999999999976 Power_divergenceResult(statistic=8393.196487932253, pvalue=0.0) Power_divergenceResult(statistic=8390.495299141596, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.042999999999999976 Power_divergenceResult(statistic=7212.394387520611, pvalue=0.0) Power_divergenceResult(statistic=8683.2001072103, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.042999999999999976 Power_divergenceResult(statistic=6170.09850345769, pvalue=0.0) Power_divergenceResult(statistic=8984.645140408002, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.042999999999999976 Power_divergenceResult(statistic=5264.994105844379, pvalue=0.0) Power_divergenceResult(statistic=9295.08720220936, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.042999999999999976 Power_divergenceResult(statistic=4495.925993110635, pvalue=0.0) Power_divergenceResult(statistic=9614.791243662978, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.042999999999999976 Power_divergenceResult(statistic=3861.897031630372, pvalue=0.0) Power_divergenceResult(statistic=9944.030621476853, pvalue=0.0)
#
# beta= 0.21899999999999983   gamma= 0.04399999999999998 Power_divergenceResult(statistic=9714.02621275183, pvalue=0.0) Power_divergenceResult(statistic=8352.470290716314, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.04399999999999998 Power_divergenceResult(statistic=8393.238983660081, pvalue=0.0) Power_divergenceResult(statistic=8643.530004809705, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.04399999999999998 Power_divergenceResult(statistic=7212.4337210235135, pvalue=0.0) Power_divergenceResult(statistic=8943.272557512435, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.04399999999999998 Power_divergenceResult(statistic=6170.134508444828, pvalue=0.0) Power_divergenceResult(statistic=9251.952785603084, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.04399999999999998 Power_divergenceResult(statistic=5265.0266038368345, pvalue=0.0) Power_divergenceResult(statistic=9569.833607567554, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.04399999999999998 Power_divergenceResult(statistic=4495.954793170305, pvalue=0.0) Power_divergenceResult(statistic=9897.186275402333, pvalue=0.0)
#
# beta= 0.21999999999999983   gamma= 0.04499999999999997 Power_divergenceResult(statistic=9714.071934631853, pvalue=0.0) Power_divergenceResult(statistic=8598.876874937241, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.04499999999999997 Power_divergenceResult(statistic=8393.28168584732, pvalue=0.0) Power_divergenceResult(statistic=8896.777709910384, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.04499999999999997 Power_divergenceResult(statistic=7212.473242088089, pvalue=0.0) Power_divergenceResult(statistic=9203.553027754124, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.04499999999999997 Power_divergenceResult(statistic=6170.170680718289, pvalue=0.0) Power_divergenceResult(statistic=9519.463595553823, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.04499999999999997 Power_divergenceResult(statistic=5265.059249596823, pvalue=0.0) Power_divergenceResult(statistic=9844.778443155868, pvalue=0.0)
#
# beta= 0.22099999999999984   gamma= 0.04599999999999997 Power_divergenceResult(statistic=9714.117863190484, pvalue=0.0) Power_divergenceResult(statistic=8845.487653486247, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.04599999999999997 Power_divergenceResult(statistic=8393.324580024004, pvalue=0.0) Power_divergenceResult(statistic=9150.22483049301, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.04599999999999997 Power_divergenceResult(statistic=7212.512942720024, pvalue=0.0) Power_divergenceResult(statistic=9464.028252447208, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.04599999999999997 Power_divergenceResult(statistic=6170.207019060992, pvalue=0.0) Power_divergenceResult(statistic=9787.164614617228, pvalue=0.0)
#
# beta= 0.22199999999999984   gamma= 0.04699999999999997 Power_divergenceResult(statistic=9714.16399856847, pvalue=0.0) Power_divergenceResult(statistic=9092.28987277459, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.04699999999999997 Power_divergenceResult(statistic=8393.367666254679, pvalue=0.0) Power_divergenceResult(statistic=9403.858913712354, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.04699999999999997 Power_divergenceResult(statistic=7212.552820104301, pvalue=0.0) Power_divergenceResult(statistic=9724.68607291741, pvalue=0.0)
#
# beta= 0.22299999999999984   gamma= 0.047999999999999966 Power_divergenceResult(statistic=9714.21034085047, pvalue=0.0) Power_divergenceResult(statistic=9339.27182290949, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.047999999999999966 Power_divergenceResult(statistic=8393.41094450441, pvalue=0.0) Power_divergenceResult(statistic=9657.668525592784, pvalue=0.0)
#
# beta= 0.22499999999999984   gamma= 0.047999999999999966 Power_divergenceResult(statistic=7212.592874312296, pvalue=0.0) Power_divergenceResult(statistic=9985.515324143975, pvalue=0.0)
#
# beta= 0.22399999999999984   gamma= 0.04899999999999997 Power_divergenceResult(statistic=9714.25688981841, pvalue=0.0) Power_divergenceResult(statistic=9586.422732795198, pvalue=0.0)
#
# beta= 0.22499999999999984   gamma= 0.04899999999999997 Power_divergenceResult(statistic=8393.45441470278, pvalue=0.0) Power_divergenceResult(statistic=9911.643148597837, pvalue=0.0)
#
# beta= 0.22499999999999984   gamma= 0.04999999999999997 Power_divergenceResult(statistic=9714.30364550195, pvalue=0.0) Power_divergenceResult(statistic=9833.732677524635, pvalue=0.0)

# %%
#Ploting
pl.plot(infected_observed, '-r', label='Infecteds Observed')
pl.plot(removed_observed, '-g', label='Recovereds Observed')

pl.legend(loc=0)
pl.title(chosen_country+', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')

# %% [markdown]
# ## SIR Validation

# %%
beta = beta_mini
gamma = gamma_mini

t_start = 0.0
t_end = 60      # Transmit Time

N = population
R0 = removed_initial
I0 = infected_initial  # Initial Number of Infectious
S0 = N - I0 - R0    # Initial Number of Susceptible

INPUT = (S0, I0, R0)

# %%
def model_SIR(INP,t):  
    Y = np.zeros((3))
    V = INP
    Y[0] = - beta * V[0] * V[1]/N                    # Y[0] is dS(t)/dt, V[0] is S(t)
    Y[1] = beta * V[0] * V[1]/N - gamma * V[1]       # Y[1] is dI(t)/dt, V[1] is I(t)
    Y[2] = gamma * V[1]                            # Y[2] is dR(t)/dt.
    return Y   # For odeint

# %%
def calculate_maximum(RES):
    infected_maximum = 0
    infected_delta_maximum = 0
    day = 0
    infected_yesterday = 0
    
    for daily_value in RES:
        if daily_value[1] > infected_maximum:
            infected_maximum = daily_value[1]
            day_maximum = day
            
        if daily_value[1]-infected_yesterday > infected_delta_maximum:
            infected_delta_maximum = daily_value[1]-infected_yesterday
            day_inflection = day
            
        day = day + 1
        infected_yesterday = daily_value[1]
        
    return infected_maximum, day_maximum, infected_delta_maximum, day_inflection

# %%
t_range = np.arange(t_start, t_end)

RES = spi.odeint(model_SIR, INPUT, t_range)   # INPUT is the first parameter of func diff_eqs
                                             # t_range is the second parameter of func diff_eqs

# %%
peak_infected, peak_day, peak_new, inflection_day = calculate_maximum(RES)

print('Peak Infected: ', f"{int(peak_infected):,d}")
print('Peak Day: ', peak_day)
print('New Case Increase Mostly: ',  f"{int(peak_new):,d}")
print('Inflection Day: ', inflection_day)

# %%
#Ploting
day = start_count_day + len(removed_observed) + 3
pl.plot(RES[:day,1], '--r', label='Infected Expected')
pl.plot(RES[:day,2], '--g', label='Recovered Expected')
pl.plot(infected_observed, '-r', label='Infected Observed')
pl.plot(removed_observed, '-g', label='Recovered Observed')

pl.legend(loc=0)
pl.title(chosen_country + ', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')

# %%
#Ploting
pl.plot(RES[:,0], '--b', label='Susceptibles')
pl.plot(RES[:,1], '--r', label='Infecteds')
pl.plot(RES[:,2], '--g', label='Recovereds')

pl.legend(loc=0)
pl.title(chosen_country + ', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')
