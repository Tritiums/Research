# %%
import scipy
from scipy import stats
import scipy.integrate as spi
import numpy as np
import pylab as pl
import pandas as pd
import math
import xlrd
import sys
import time

# %matplotlib inline

# %%
filename = 'coronaData.xlsx'
book = xlrd.open_workbook(filename)
print('Source file: ' + sys.path[0] + filename + ' loaded!')

#Extraction
nsheets = book.nsheets

sheet_names = book.sheet_names()
sheets = {}

for sheet_name in sheet_names:    
    nrows = book.sheet_by_name(sheet_name).nrows
    current_header = book.sheet_by_name(sheet_name).row_values(0) 
    current_data = [book.sheet_by_name(sheet_name).row_values(i) for i in range(1, nrows)]
    sheets[sheet_name] = pd.DataFrame(current_data, columns = current_header)   #DataFrame Construction
#Feedback
print('Data Extracted!')
# Out:
# Source file: I:\Chuan\Documents\GitHub\Research\SEIRcoronaData.xlsx loaded!
# Data Extracted!

# %%
sheet_names
# Out:
# ['Italy', 'SouthKorea', 'France', 'Germany', 'Spain', 'US', 'China']

# %%
chosen_country = 'US'
population = 327 * math.pow(10,6)
infected_initial = 11
removed_initial = 3

start_count_day = 18
# Population
# China(Wuhan): 7e6, Italy: 49e6, Germany 81e6, Spain: 47e6, France: 64e6, US: 327e6, SouthKorea: 506e6

# %%
sheets[chosen_country]
# Out:
#                  infected  recovered  death
# 0   22-JAN-2020       1.0        0.0    0.0
# 1   23-JAN-2020       1.0        0.0    0.0
# 2   24-JAN-2020       2.0        0.0    0.0
# 3   25-JAN-2020       2.0        0.0    0.0
# 4   26-JAN-2020       5.0        0.0    0.0
# 5   27-JAN-2020       5.0        0.0    0.0
# 6   28-JAN-2020       5.0        0.0    0.0
# 7   29-JAN-2020       5.0        0.0    0.0
# 8   30-JAN-2020       5.0        0.0    0.0
# 9   31-JAN-2020       7.0        0.0    0.0
# 10  01-FEB-2020       8.0        0.0    0.0
# 11  02-FEB-2020       8.0        0.0    0.0
# 12  03-FEB-2020      11.0        0.0    0.0
# 13  04-FEB-2020      11.0        0.0    0.0
# 14  05-FEB-2020      11.0        0.0    0.0
# 15  06-FEB-2020      11.0        0.0    0.0
# 16  07-FEB-2020      11.0        0.0    0.0
# 17  08-FEB-2020      11.0        0.0    0.0
# 18  09-FEB-2020      11.0        3.0    0.0
# 19  10-FEB-2020      11.0        3.0    0.0
# 20  11-FEB-2020      12.0        3.0    0.0
# 21  12-FEB-2020      12.0        3.0    0.0
# 22  13-FEB-2020      13.0        3.0    0.0
# 23  14-FEB-2020      13.0        3.0    0.0
# 24  15-FEB-2020      13.0        3.0    0.0
# 25  16-FEB-2020      13.0        3.0    0.0
# 26  17-FEB-2020      13.0        3.0    0.0
# 27  18-FEB-2020      13.0        3.0    0.0
# 28  19-FEB-2020      13.0        3.0    0.0
# 29  20-FEB-2020      13.0        3.0    0.0
# 30  21-FEB-2020      15.0        5.0    0.0
# 31  22-FEB-2020      15.0        5.0    0.0
# 32  23-FEB-2020      15.0        5.0    0.0
# 33  24-FEB-2020      51.0        5.0    0.0
# 34  25-FEB-2020      51.0        6.0    0.0
# 35  26-FEB-2020      57.0        6.0    0.0
# 36  27-FEB-2020      58.0        6.0    0.0
# 37  28-FEB-2020      60.0        7.0    0.0
# 38  29-FEB-2020      68.0        7.0    1.0
# 39  01-MAR-2020      74.0        7.0    1.0
# 40  02-MAR-2020      98.0        7.0    6.0
# 41  03-MAR-2020     118.0        7.0    7.0
# 42  04-MAR-2020     149.0        7.0   11.0
# 43  05-MAR-2020     217.0        7.0   12.0
# 44  06-MAR-2020     262.0        7.0   14.0
# 45  07-MAR-2020     402.0        7.0   17.0
# 46  08-MAR-2020     518.0        7.0   21.0
# 47  09-MAR-2020     583.0        7.0   22.0
# 48  10-MAR-2020     959.0        8.0   28.0
# 49  11-MAR-2020    1281.0        8.0   36.0
# 50  12-MAR-2020    1663.0       12.0   40.0
# 51  13-MAR-2020    2179.0       12.0   47.0
# 52  14-MAR-2020    2727.0       12.0   54.0
# 53  15-MAR-2020    3499.0       12.0   63.0
# 54  16-MAR-2020    4632.0       17.0   85.0

# %%
infected_observed = sheets[chosen_country]['infected'][start_count_day:]

removed_observed = sheets[chosen_country]['recovered'][start_count_day:] + sheets[chosen_country]['death'][start_count_day:]

# %%
len(removed_observed)
# Out:
# 37

# %% [markdown]
# ## Iteratible SIR Model

# %%
t_start = 0.0
t_end = len(removed_observed) + 1       # Transmit Time

N = population
R0 = removed_initial
I0 = infected_initial      # Initial Number of Infectious
S0 = N - I0 - R0    # Initial Number of Susceptible

INPUT = (S0, I0, R0)

def model_SIR(INP,t):  
    Y = np.zeros((3))
    V = INP
    Y[0] = - beta * V[0] * V[1]/N                    # Y[0] is dS(t)/dt, V[0] is S(t)
    Y[1] = beta * V[0] * V[1]/N - gamma * V[1]       # Y[1] is dI(t)/dt, V[1] is I(t)
    Y[2] = gamma * V[1]                            # Y[2] is dR(t)/dt.
    return Y   # For odeint

t_range = np.arange(t_start, t_end)

# %% [markdown]
# ### Start Interation

# %%
start = time.time()

minimum_infected = math.pow(10,10)
minimum_removed = math.pow(10,10)

for gamma in np.arange(0.01, 4.0, 0.01):
    for beta in np.arange(0.01, 4.0, 0.01):
        RES = spi.odeint(model_SIR, INPUT, t_range) 
        
        # Goodness Test of Fitness
        
        #print(RES)
        
        fitness_infected = stats.chisquare(infected_observed, RES[1:, 1])
        fitness_removed = stats.chisquare(removed_observed, RES[1:, 2])
        
       
        if abs(fitness_infected[0]) < 10000 and abs(fitness_removed[0]) < 10000:
            print('\nbeta=', beta, '  gamma=', gamma, fitness_infected, fitness_removed)
        
        
        #print('beta=', beta, '  gamma=', gamma, fitness_infected, fitness_removed)
            
        if abs(fitness_infected[0]) < minimum_infected and abs(fitness_removed[0]) < minimum_removed:
            minimum_infected = fitness_infected[0]
            minimum_removed = fitness_removed[0]
            beta_mini = beta
            gamma_mini = gamma
            
end = time.time()
duration = end - start
            
print('\nThe minimum_infected Z is ', minimum_infected)
print('The minimum_removed Z is ', minimum_removed)
print('when beta is ', beta_mini)
print('when gamma is ', gamma_mini)

print('Time: ', duration)
# Out:
# beta= 0.15000000000000002   gamma= 0.01 Power_divergenceResult(statistic=9056.157691395112, pvalue=0.0) Power_divergenceResult(statistic=181.08505696048795, pvalue=3.0359862808628103e-21)
#
# beta= 0.16   gamma= 0.01 Power_divergenceResult(statistic=4420.730386683191, pvalue=0.0) Power_divergenceResult(statistic=383.3913355167218, pvalue=1.0991605454357987e-59)
#
# beta= 0.17   gamma= 0.01 Power_divergenceResult(statistic=4778.341297850562, pvalue=0.0) Power_divergenceResult(statistic=694.7942590757544, pvalue=6.195033965797037e-123)
#
# beta= 0.16   gamma= 0.02 Power_divergenceResult(statistic=9056.175025769613, pvalue=0.0) Power_divergenceResult(statistic=1014.2617654740226, pvalue=1.6091846921508234e-189)
#
# beta= 0.17   gamma= 0.02 Power_divergenceResult(statistic=4420.7398467025505, pvalue=0.0) Power_divergenceResult(statistic=1545.8050991882776, pvalue=7.751500321011993e-302)
#
# beta= 0.18000000000000002   gamma= 0.02 Power_divergenceResult(statistic=4778.337623824429, pvalue=0.0) Power_divergenceResult(statistic=2269.500713535736, pvalue=0.0)
#
# beta= 0.17   gamma= 0.03 Power_divergenceResult(statistic=9056.193458331285, pvalue=0.0) Power_divergenceResult(statistic=1976.7873958677642, pvalue=0.0)
#
# beta= 0.18000000000000002   gamma= 0.03 Power_divergenceResult(statistic=4420.749874695889, pvalue=0.0) Power_divergenceResult(statistic=2811.1410722988076, pvalue=0.0)
#
# beta= 0.19   gamma= 0.03 Power_divergenceResult(statistic=4778.333746722883, pvalue=0.0) Power_divergenceResult(statistic=3925.953978807227, pvalue=0.0)
#
# beta= 0.18000000000000002   gamma= 0.04 Power_divergenceResult(statistic=9056.212989081409, pvalue=0.0) Power_divergenceResult(statistic=2973.606968601115, pvalue=0.0)
#
# beta= 0.19   gamma= 0.04 Power_divergenceResult(statistic=4420.7604706687525, pvalue=0.0) Power_divergenceResult(statistic=4103.719577172316, pvalue=0.0)
#
# beta= 0.2   gamma= 0.04 Power_divergenceResult(statistic=4778.329666556382, pvalue=0.0) Power_divergenceResult(statistic=5604.050619763224, pvalue=0.0)
#
# beta= 0.19   gamma= 0.05 Power_divergenceResult(statistic=9056.233639081816, pvalue=0.0) Power_divergenceResult(statistic=3984.5851348433794, pvalue=0.0)
#
# beta= 0.2   gamma= 0.05 Power_divergenceResult(statistic=4420.771634647435, pvalue=0.0) Power_divergenceResult(statistic=5407.553193345544, pvalue=0.0)
#
# beta= 0.21000000000000002   gamma= 0.05 Power_divergenceResult(statistic=4778.325383337137, pvalue=0.0) Power_divergenceResult(statistic=7291.104700043413, pvalue=0.0)
#
# beta= 0.2   gamma= 0.060000000000000005 Power_divergenceResult(statistic=9056.25541898928, pvalue=0.0) Power_divergenceResult(statistic=5002.800752452082, pvalue=0.0)
#
# beta= 0.21000000000000002   gamma= 0.060000000000000005 Power_divergenceResult(statistic=4420.783381486188, pvalue=0.0) Power_divergenceResult(statistic=6717.147059237775, pvalue=0.0)
#
# beta= 0.22   gamma= 0.060000000000000005 Power_divergenceResult(statistic=4778.320882026721, pvalue=0.0) Power_divergenceResult(statistic=8982.751972588985, pvalue=0.0)
#
# beta= 0.21000000000000002   gamma= 0.06999999999999999 Power_divergenceResult(statistic=9056.27827546475, pvalue=0.0) Power_divergenceResult(statistic=6025.223797780138, pvalue=0.0)
#
# beta= 0.22   gamma= 0.06999999999999999 Power_divergenceResult(statistic=4420.7956868514975, pvalue=0.0) Power_divergenceResult(statistic=8030.094070927156, pvalue=0.0)
#
# beta= 0.22   gamma= 0.08 Power_divergenceResult(statistic=9056.302217615917, pvalue=0.0) Power_divergenceResult(statistic=7050.314057813117, pvalue=0.0)
#
# beta= 0.23   gamma= 0.08 Power_divergenceResult(statistic=4420.808557447049, pvalue=0.0) Power_divergenceResult(statistic=9345.16953484374, pvalue=0.0)
#
# beta= 0.23   gamma= 0.09 Power_divergenceResult(statistic=9056.327252307145, pvalue=0.0) Power_divergenceResult(statistic=8077.204149804113, pvalue=0.0)
#
# beta= 0.24000000000000002   gamma= 0.09999999999999999 Power_divergenceResult(statistic=9056.353004481278, pvalue=0.0) Power_divergenceResult(statistic=9105.367759361048, pvalue=0.0)
#
# The minimum_infected Z is  36708.36358217052
# The minimum_removed Z is  34.4089128367051
# when beta is  0.13
# when gamma is  0.01
# Time:  255.11807441711426

# %%
#Ploting
pl.plot(infected_observed, '-r', label='Infecteds Observed')
pl.plot(removed_observed, '-g', label='Recovereds Observed')

pl.legend(loc=0)
pl.title(chosen_country+', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')
# Out:
# Text(0, 0.5, 'Infectious and Recovereds')

# %% [markdown]
# ## SIR Validation

# %%
beta = beta_mini
gamma = gamma_mini

t_start = 0.0
t_end = 300      # Transmit Time

N = population
R0 = removed_initial
I0 = infected_initial  # Initial Number of Infectious
S0 = N - I0 - R0    # Initial Number of Susceptible

INPUT = (S0, I0, R0)

# %%
def model_SIR(INP,t):  
    Y = np.zeros((3))
    V = INP
    Y[0] = - beta * V[0] * V[1]/N                    # Y[0] is dS(t)/dt, V[0] is S(t)
    Y[1] = beta * V[0] * V[1]/N - gamma * V[1]       # Y[1] is dI(t)/dt, V[1] is I(t)
    Y[2] = gamma * V[1]                            # Y[2] is dR(t)/dt.
    return Y   # For odeint

# %%
def calculate_maximum(RES):
    infected_maximum = 0
    infected_delta_maximum = 0
    day = 0
    infected_yesterday = 0
    
    for daily_value in RES:
        if daily_value[1] > infected_maximum:
            infected_maximum = daily_value[1]
            day_maximum = day
            
        if daily_value[1]-infected_yesterday > infected_delta_maximum:
            infected_delta_maximum = daily_value[1]-infected_yesterday
            day_inflection = day
            
        day = day + 1
        infected_yesterday = daily_value[1]
        
    return infected_maximum, day_maximum, infected_delta_maximum, day_inflection

# %%
t_range = np.arange(t_start, t_end)

RES = spi.odeint(model_SIR, INPUT, t_range)   # INPUT is the first parameter of func diff_eqs
                                             # t_range is the second parameter of func diff_eqs

# %%
peak_infected, peak_day, peak_new, inflection_day = calculate_maximum(RES)

print('Peak Infected: ', peak_infected)
print('Peak Day: ', peak_day)
print('New Case Increase Mostly: ', peak_new)
print('Inflection Day: ', inflection_day)
# Out:
# Peak Infected:  237311683.86558542
# Peak Day:  166
# New Case Increase Mostly:  8121698.112977043
# Inflection Day:  142

# %%
RES
# Out:
# array([[3.26999986e+08, 1.10000000e+01, 3.00000000e+00],
#        [3.26999984e+08, 1.24024652e+01, 3.11687210e+00],
#        [3.26999983e+08, 1.39837405e+01, 3.24864505e+00],
#        [3.26999981e+08, 1.57666232e+01, 3.39721862e+00],
#        [3.26999979e+08, 1.77768179e+01, 3.56473486e+00],
#        [3.26999976e+08, 2.00433061e+01, 3.75360889e+00],
#        [3.26999973e+08, 2.25987648e+01, 3.96656380e+00],
#        [3.26999970e+08, 2.54800356e+01, 4.20666972e+00],
#        [3.26999967e+08, 2.87286596e+01, 4.47738842e+00],
#        [3.26999963e+08, 3.23914728e+01, 4.78262289e+00],
#        [3.26999958e+08, 3.65212831e+01, 5.12677379e+00],
#        [3.26999953e+08, 4.11776311e+01, 5.51480284e+00],
#        [3.26999948e+08, 4.64276486e+01, 5.95230437e+00],
#        [3.26999941e+08, 5.23470267e+01, 6.44558598e+00],
#        [3.26999934e+08, 5.90211063e+01, 7.00175939e+00],
#        [3.26999926e+08, 6.65461095e+01, 7.62884313e+00],
#        [3.26999917e+08, 7.50305267e+01, 8.33587808e+00],
#        [3.26999906e+08, 8.45966797e+01, 9.13305774e+00],
#        [3.26999895e+08, 9.53824863e+01, 1.00318752e+01],
#        [3.26999881e+08, 1.07543448e+02, 1.10452891e+01],
#        [3.26999867e+08, 1.21254893e+02, 1.21879100e+01],
#        [3.26999850e+08, 1.36714503e+02, 1.34762114e+01],
#        [3.26999831e+08, 1.54145162e+02, 1.49287672e+01],
#        [3.26999810e+08, 1.73798173e+02, 1.65665190e+01],
#        [3.26999786e+08, 1.95956878e+02, 1.84130790e+01],
#        [3.26999759e+08, 2.20940743e+02, 2.04950693e+01],
#        [3.26999728e+08, 2.49109968e+02, 2.28425067e+01],
#        [3.26999694e+08, 2.80870672e+02, 2.54892346e+01],
#        [3.26999655e+08, 3.16680758e+02, 2.84734117e+01],
#        [3.26999611e+08, 3.57056507e+02, 3.18380615e+01],
#        [3.26999562e+08, 4.02580022e+02, 3.56316930e+01],
#        [3.26999506e+08, 4.53907624e+02, 3.99089997e+01],
#        [3.26999443e+08, 5.11779312e+02, 4.47316487e+01],
#        [3.26999373e+08, 5.77029428e+02, 5.01691691e+01],
#        [3.26999293e+08, 6.50598693e+02, 5.62999547e+01],
#        [3.26999203e+08, 7.33547760e+02, 6.32123942e+01],
#        [3.26999102e+08, 8.27072513e+02, 7.10061455e+01],
#        [3.26998988e+08, 9.32521303e+02, 7.97935725e+01],
#        [3.26998859e+08, 1.05141439e+03, 8.97013648e+01],
#        [3.41456159e+04, 9.63784953e+07, 2.30587359e+08],
#        [3.28683200e+04, 9.54207841e+07, 2.31546348e+08],
#        [3.16507932e+04, 9.44725429e+07, 2.32495806e+08],
#        [3.04898015e+04, 9.35336805e+07, 2.33435830e+08],
#        [2.93823070e+04, 9.26041068e+07, 2.34366511e+08],
#        [2.83254546e+04, 9.16837321e+07, 2.35287942e+08],
#        [2.73165598e+04, 9.07724675e+07, 2.36200216e+08],
#        [2.63530978e+04, 8.98702250e+07, 2.37103422e+08],
#        [2.54326929e+04, 8.89769171e+07, 2.37997650e+08],
#        [2.45531089e+04, 8.80924572e+07, 2.38882990e+08],
#        [2.37122401e+04, 8.72167592e+07, 2.39759529e+08],
#        [2.29081026e+04, 8.63497381e+07, 2.40627354e+08],
#        [2.21388271e+04, 8.54913092e+07, 2.41486552e+08],
#        [2.14026512e+04, 8.46413890e+07, 2.42337208e+08],
#        [2.06979129e+04, 8.37998943e+07, 2.43179408e+08],
#        [2.00230440e+04, 8.29667429e+07, 2.44013234e+08],
#        [1.93765647e+04, 8.21418532e+07, 2.44838770e+08],
#        [1.87570777e+04, 8.13251445e+07, 2.45656098e+08],
#        [1.81632634e+04, 8.05165366e+07, 2.46465300e+08],
#        [1.75938750e+04, 7.97159502e+07, 2.47266456e+08],
#        [1.70477341e+04, 7.89233067e+07, 2.48059646e+08],
#        [1.65237264e+04, 7.81385280e+07, 2.48844948e+08],
#        [1.60207983e+04, 7.73615371e+07, 2.49622442e+08],
#        [1.55379526e+04, 7.65922574e+07, 2.50392205e+08],
#        [1.50742458e+04, 7.58306131e+07, 2.51154313e+08],
#        [1.46287845e+04, 7.50765291e+07, 2.51908842e+08],
#        [1.42007225e+04, 7.43299310e+07, 2.52655868e+08],
#        [1.37892582e+04, 7.35907453e+07, 2.53395465e+08],
#        [1.33936318e+04, 7.28588988e+07, 2.54127708e+08],
#        [1.30131230e+04, 7.21343192e+07, 2.54852668e+08],
#        [1.26470488e+04, 7.14169350e+07, 2.55570418e+08],
#        [1.22947613e+04, 7.07066751e+07, 2.56281030e+08],
#        [1.19556454e+04, 7.00034694e+07, 2.56984575e+08]])

# %%
#Ploting
day = start_count_day + len(removed_observed) + 3
pl.plot(RES[:day,1], '--r', label='Infected Expected')
pl.plot(RES[:day,2], '--g', label='Recovered Expected')
pl.plot(infected_observed, '-r', label='Infected Observed')
pl.plot(removed_observed, '-g', label='Recovered Observed')

pl.legend(loc=0)
pl.title(chosen_country + ', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')
# Out:
# Text(0, 0.5, 'Infectious and Recovereds')

# %%
#Ploting
pl.plot(RES[:,0], '--b', label='Susceptibles')
pl.plot(RES[:,1], '--r', label='Infecteds')
pl.plot(RES[:,2], '--g', label='Recovereds')

pl.legend(loc=0)
pl.title(chosen_country + ', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')
# Out:
# Text(0, 0.5, 'Infectious and Recovereds')
