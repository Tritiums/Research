# %%
import scipy
from scipy import stats
import scipy.integrate as spi
import numpy as np
import pylab as pl
import pandas as pd
import math
import xlrd
import sys
import time

# %matplotlib inline

# %%
filename = 'coronaData.xlsx'
book = xlrd.open_workbook(filename)
print('Source file: ' + sys.path[0] + filename + ' loaded!')

#Extraction
nsheets = book.nsheets

sheet_names = book.sheet_names()
sheets = {}

for sheet_name in sheet_names:    
    nrows = book.sheet_by_name(sheet_name).nrows
    current_header = book.sheet_by_name(sheet_name).row_values(0) 
    current_data = [book.sheet_by_name(sheet_name).row_values(i) for i in range(1, nrows)]
    sheets[sheet_name] = pd.DataFrame(current_data, columns = current_header)   #DataFrame Construction
#Feedback
print('Data Extracted!')
# Out:
# Source file: I:\Chuan\Documents\GitHub\Research\SEIRcoronaData.xlsx loaded!
# Data Extracted!

# %%
sheet_names
# Out:
# ['Italy', 'SouthKorea', 'France', 'Germany', 'Spain', 'US', 'China']

# %%
chosen_country = 'Germany'
population = 81 * math.pow(10,6)
infected_initial = 16
removed_initial = 1

# Population
# China(Wuhan): 7e6, Italy: 49e6, Germany 81e6, Spain: 47e6, France: 64e6, US: 327e6, SouthKorea: 506e6

# %%
sheets[chosen_country]
# Out:
#                  infected  recovered  death
# 0   22-JAN-2020       0.0        0.0    0.0
# 1   23-JAN-2020       0.0        0.0    0.0
# 2   24-JAN-2020       0.0        0.0    0.0
# 3   25-JAN-2020       0.0        0.0    0.0
# 4   26-JAN-2020       0.0        0.0    0.0
# 5   27-JAN-2020       1.0        0.0    0.0
# 6   28-JAN-2020       4.0        0.0    0.0
# 7   29-JAN-2020       4.0        0.0    0.0
# 8   30-JAN-2020       4.0        0.0    0.0
# 9   31-JAN-2020       5.0        0.0    0.0
# 10  01-FEB-2020       8.0        0.0    0.0
# 11  02-FEB-2020      10.0        0.0    0.0
# 12  03-FEB-2020      12.0        0.0    0.0
# 13  04-FEB-2020      12.0        0.0    0.0
# 14  05-FEB-2020      12.0        0.0    0.0
# 15  06-FEB-2020      12.0        0.0    0.0
# 16  07-FEB-2020      13.0        0.0    0.0
# 17  08-FEB-2020      13.0        0.0    0.0
# 18  09-FEB-2020      14.0        0.0    0.0
# 19  10-FEB-2020      14.0        0.0    0.0
# 20  11-FEB-2020      16.0        0.0    0.0
# 21  12-FEB-2020      16.0        0.0    0.0
# 22  13-FEB-2020      16.0        1.0    0.0
# 23  14-FEB-2020      16.0        1.0    0.0
# 24  15-FEB-2020      16.0        1.0    0.0
# 25  16-FEB-2020      16.0        1.0    0.0
# 26  17-FEB-2020      16.0        1.0    0.0
# 27  18-FEB-2020      16.0       12.0    0.0
# 28  19-FEB-2020      16.0       12.0    0.0
# 29  20-FEB-2020      16.0       12.0    0.0
# 30  21-FEB-2020      16.0       14.0    0.0
# 31  22-FEB-2020      16.0       14.0    0.0
# 32  23-FEB-2020      16.0       14.0    0.0
# 33  24-FEB-2020      16.0       14.0    0.0
# 34  25-FEB-2020      17.0       14.0    0.0
# 35  26-FEB-2020      27.0       15.0    0.0
# 36  27-FEB-2020      46.0       16.0    0.0
# 37  28-FEB-2020      48.0       16.0    0.0
# 38  29-FEB-2020      79.0       16.0    0.0
# 39  01-MAR-2020     130.0       16.0    0.0
# 40  02-MAR-2020     159.0       16.0    0.0
# 41  03-MAR-2020     196.0       16.0    0.0
# 42  04-MAR-2020     262.0       16.0    0.0
# 43  05-MAR-2020     482.0       16.0    0.0
# 44  06-MAR-2020     670.0       17.0    0.0
# 45  07-MAR-2020     799.0       18.0    0.0
# 46  08-MAR-2020    1040.0       18.0    0.0
# 47  09-MAR-2020    1176.0       18.0    2.0
# 48  10-MAR-2020    1457.0       18.0    2.0
# 49  11-MAR-2020    1908.0       25.0    3.0
# 50  12-MAR-2020    2078.0       25.0    3.0
# 51  13-MAR-2020    3675.0       46.0    7.0
# 52  14-MAR-2020    4585.0       46.0    9.0
# 53  15-MAR-2020    5795.0       46.0   11.0
# 54  16-MAR-2020    7272.0       67.0   17.0

# %%
start_count_day = 22

# %%
infected_observed = sheets[chosen_country]['infected'][start_count_day:]

removed_observed = sheets[chosen_country]['recovered'][start_count_day:] + sheets[chosen_country]['death'][start_count_day:]

# %%
len(removed_observed)
# Out:
# 33

# %% [markdown]
# ## Iteratible SIR Model

# %%
t_start = 0.0
t_end = len(removed_observed) + 1       # Transmit Time

N = population
R0 = removed_initial
I0 = infected_initial      # Initial Number of Infectious
S0 = N - I0 - R0    # Initial Number of Susceptible

INPUT = (S0, I0, R0)

def model_SIR(INP,t):  
    Y = np.zeros((3))
    V = INP
    Y[0] = - beta * V[0] * V[1]/N                    # Y[0] is dS(t)/dt, V[0] is S(t)
    Y[1] = beta * V[0] * V[1]/N - gamma * V[1]       # Y[1] is dI(t)/dt, V[1] is I(t)
    Y[2] = gamma * V[1]                            # Y[2] is dR(t)/dt.
    return Y   # For odeint

t_range = np.arange(t_start, t_end)

# %% [markdown]
# ### Start Interation

# %%
start = time.time()

minimum_infected = math.pow(10,10)
minimum_removed = math.pow(10,10)

for gamma in np.arange(0.01, 4.0, 0.01):
    for beta in np.arange(0.01, 4.0, 0.01):
        RES = spi.odeint(model_SIR, INPUT, t_range) 
        
        # Goodness Test of Fitness
        
        #print(RES)
        
        fitness_infected = stats.chisquare(infected_observed, RES[1:, 1])
        fitness_removed = stats.chisquare(removed_observed, RES[1:, 2])
        
       
        if abs(fitness_infected[0]) < 10000 and abs(fitness_removed[0]) < 10000:
            print('\nbeta=', beta, '  gamma=', gamma, fitness_infected, fitness_removed)
        
        
        #print('beta=', beta, '  gamma=', gamma, fitness_infected, fitness_removed)
            
        if abs(fitness_infected[0]) < minimum_infected and abs(fitness_removed[0]) < minimum_removed:
            minimum_infected = fitness_infected[0]
            minimum_removed = fitness_removed[0]
            beta_mini = beta
            gamma_mini = gamma
            
end = time.time()
duration = end - start
            
print('\nThe minimum_infected Z is ', minimum_infected)
print('The minimum_removed Z is ', minimum_removed)
print('when beta is ', beta_mini)
print('when gamma is ', gamma_mini)

print('Time: ', duration)
# Out:
# beta= 0.18000000000000002   gamma= 0.01 Power_divergenceResult(statistic=6048.3422849055405, pvalue=0.0) Power_divergenceResult(statistic=880.3912036322093, pvalue=2.39158667805354e-164)
#
# beta= 0.19   gamma= 0.01 Power_divergenceResult(statistic=3838.661907442623, pvalue=0.0) Power_divergenceResult(statistic=1237.2058765864986, pvalue=1.2867088576928618e-239)
#
# beta= 0.2   gamma= 0.01 Power_divergenceResult(statistic=7603.45890815976, pvalue=0.0) Power_divergenceResult(statistic=1716.5097172097703, pvalue=0.0)
#
# beta= 0.19   gamma= 0.02 Power_divergenceResult(statistic=6048.44944958084, pvalue=0.0) Power_divergenceResult(statistic=2240.147966753625, pvalue=0.0)
#
# beta= 0.2   gamma= 0.02 Power_divergenceResult(statistic=3838.6812407677676, pvalue=0.0) Power_divergenceResult(statistic=3028.53741385358, pvalue=0.0)
#
# beta= 0.21000000000000002   gamma= 0.02 Power_divergenceResult(statistic=7603.333221335694, pvalue=0.0) Power_divergenceResult(statistic=4051.870839441767, pvalue=0.0)
#
# beta= 0.2   gamma= 0.03 Power_divergenceResult(statistic=6048.562414246196, pvalue=0.0) Power_divergenceResult(statistic=3755.3262360085, pvalue=0.0)
#
# beta= 0.21000000000000002   gamma= 0.03 Power_divergenceResult(statistic=3838.701555579482, pvalue=0.0) Power_divergenceResult(statistic=4960.444485734839, pvalue=0.0)
#
# beta= 0.22   gamma= 0.03 Power_divergenceResult(statistic=7603.201383769837, pvalue=0.0) Power_divergenceResult(statistic=6515.006895813688, pvalue=0.0)
#
# beta= 0.21000000000000002   gamma= 0.04 Power_divergenceResult(statistic=6048.68109292249, pvalue=0.0) Power_divergenceResult(statistic=5314.279162621167, pvalue=0.0)
#
# beta= 0.22   gamma= 0.04 Power_divergenceResult(statistic=3838.722889039131, pvalue=0.0) Power_divergenceResult(statistic=6931.992999596045, pvalue=0.0)
#
# beta= 0.23   gamma= 0.04 Power_divergenceResult(statistic=7603.063521364488, pvalue=0.0) Power_divergenceResult(statistic=9014.202731350451, pvalue=0.0)
#
# beta= 0.22   gamma= 0.05 Power_divergenceResult(statistic=6048.805334454231, pvalue=0.0) Power_divergenceResult(statistic=6891.7406618989735, pvalue=0.0)
#
# beta= 0.23   gamma= 0.05 Power_divergenceResult(statistic=3838.7452930981685, pvalue=0.0) Power_divergenceResult(statistic=8920.30604662306, pvalue=0.0)
#
# beta= 0.23   gamma= 0.060000000000000005 Power_divergenceResult(statistic=6048.935475368249, pvalue=0.0) Power_divergenceResult(statistic=8478.765959338492, pvalue=0.0)
#
# The minimum_infected Z is  140815.85438446535
# The minimum_removed Z is  250.02243730576868
# when beta is  0.13
# when gamma is  0.01
# Time:  252.72885394096375

# %%
#Ploting
pl.plot(infected_observed, '-r', label='Infecteds Observed')
pl.plot(removed_observed, '-g', label='Recovereds Observed')

pl.legend(loc=0)
pl.title(chosen_country+', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')
# Out:
# Text(0, 0.5, 'Infectious and Recovereds')

# %% [markdown]
# ## SIR Validation

# %%
beta = 0.13
gamma = 0.01

t_start = 0.0
t_end = 300      # Transmit Time

N = population
R0 = removed_initial
I0 = infected_initial  # Initial Number of Infectious
S0 = N - I0 - R0    # Initial Number of Susceptible

INPUT = (S0, I0, R0)

# %%
def model_SIR(INP,t):  
    Y = np.zeros((3))
    V = INP
    Y[0] = - beta * V[0] * V[1]/N                    # Y[0] is dS(t)/dt, V[0] is S(t)
    Y[1] = beta * V[0] * V[1]/N - gamma * V[1]       # Y[1] is dI(t)/dt, V[1] is I(t)
    Y[2] = gamma * V[1]                            # Y[2] is dR(t)/dt.
    return Y   # For odeint

# %%
def calculate_maximum(RES):
    infected_maximum = 0
    infected_delta_maximum = 0
    day = 0
    infected_yesterday = 0
    
    for daily_value in RES:
        if daily_value[1] > infected_maximum:
            infected_maximum = daily_value[1]
            day_maximum = day
            
        if daily_value[1]-infected_yesterday > infected_delta_maximum:
            infected_delta_maximum = daily_value[1]-infected_yesterday
            day_inflection = day
            
        day = day + 1
        infected_yesterday = daily_value[1]
        
    return infected_maximum, day_maximum, infected_delta_maximum, day_inflection

# %%
t_range = np.arange(t_start, t_end)

RES = spi.odeint(model_SIR, INPUT, t_range)   # INPUT is the first parameter of func diff_eqs
                                             # t_range is the second parameter of func diff_eqs

# %%
peak_infected, peak_day, peak_new, inflection_day = calculate_maximum(RES)

print('Peak Infected: ', peak_infected)
print('Peak Day: ', peak_day)
print('New Case Increase Mostly: ', peak_new)
print('Inflection Day: ', inflection_day)
# Out:
# Peak Infected:  58787131.20863952
# Peak Day:  151
# New Case Increase Mostly:  2011829.784691099
# Inflection Day:  127

# %%
RES
# Out:
# array([[8.09999830e+07, 1.60000000e+01, 1.00000000e+00],
#        [8.09999808e+07, 1.80399490e+01, 1.16999579e+00],
#        [8.09999783e+07, 2.03399851e+01, 1.36166552e+00],
#        [8.09999755e+07, 2.29332683e+01, 1.57777252e+00],
#        [8.09999723e+07, 2.58571867e+01, 1.82143247e+00],
#        [8.09999687e+07, 2.91538954e+01, 2.09615830e+00],
#        [8.09999647e+07, 3.28709242e+01, 2.40591084e+00],
#        [8.09999602e+07, 3.70618609e+01, 2.75515574e+00],
#        [8.09999551e+07, 4.17871287e+01, 3.14892828e+00],
#        [8.09999493e+07, 4.71148525e+01, 3.59290555e+00],
#        [8.09999428e+07, 5.31218434e+01, 4.09348848e+00],
#        [8.09999354e+07, 5.98947054e+01, 4.65789411e+00],
#        [8.09999272e+07, 6.75310844e+01, 5.29425962e+00],
#        [8.09999178e+07, 7.61410760e+01, 6.01175966e+00],
#        [8.09999073e+07, 8.58488114e+01, 6.82073855e+00],
#        [8.09998955e+07, 9.67942490e+01, 7.73285956e+00],
#        [8.09998821e+07, 1.09135192e+02, 8.76127297e+00],
#        [8.09998670e+07, 1.23049560e+02, 9.92080564e+00],
#        [8.09998500e+07, 1.38737961e+02, 1.12281748e+01],
#        [8.09998309e+07, 1.56426574e+02, 1.27022291e+01],
#        [8.09998093e+07, 1.76370419e+02, 1.43642201e+01],
#        [8.09997849e+07, 1.98857027e+02, 1.62381093e+01],
#        [8.09997574e+07, 2.24210591e+02, 1.83509127e+01],
#        [8.09997265e+07, 2.52796631e+02, 2.07330909e+01],
#        [8.09996916e+07, 2.85027273e+02, 2.34189882e+01],
#        [8.09996522e+07, 3.21367185e+02, 2.64473275e+01],
#        [8.09996078e+07, 3.62340275e+02, 2.98617686e+01],
#        [5.34610770e+03, 2.10182936e+07, 5.99763603e+07],
#        [5.16964314e+03, 2.08093337e+07, 6.01854967e+07],
#        [5.00067179e+03, 2.06024455e+07, 6.03925538e+07],
#        [4.83882177e+03, 2.03976088e+07, 6.05975524e+07],
#        [4.68374202e+03, 2.01948035e+07, 6.08005128e+07],
#        [4.53510099e+03, 1.99940097e+07, 6.10014552e+07],
#        [4.39258546e+03, 1.97952078e+07, 6.12003996e+07],
#        [4.25589943e+03, 1.95983782e+07, 6.13973659e+07],
#        [4.12476306e+03, 1.94035015e+07, 6.15923737e+07],
#        [3.99891167e+03, 1.92105587e+07, 6.17854424e+07],
#        [3.87809491e+03, 1.90195307e+07, 6.19765912e+07],
#        [3.76207581e+03, 1.88303986e+07, 6.21658393e+07],
#        [3.65063006e+03, 1.86431439e+07, 6.23532055e+07],
#        [3.54354521e+03, 1.84577481e+07, 6.25387084e+07],
#        [3.44062002e+03, 1.82741928e+07, 6.27223666e+07],
#        [3.34166377e+03, 1.80924600e+07, 6.29041983e+07],
#        [3.24649569e+03, 1.79125317e+07, 6.30842218e+07],
#        [3.15494432e+03, 1.77343901e+07, 6.32624549e+07],
#        [3.06684705e+03, 1.75580177e+07, 6.34389155e+07],
#        [2.98204957e+03, 1.73833968e+07, 6.36136211e+07],
#        [2.90040542e+03, 1.72105104e+07, 6.37865892e+07],
#        [2.82177553e+03, 1.70393412e+07, 6.39578370e+07],
#        [2.74602781e+03, 1.68698723e+07, 6.41273817e+07],
#        [2.67303679e+03, 1.67020869e+07, 6.42952401e+07],
#        [2.60268319e+03, 1.65359683e+07, 6.44614290e+07],
#        [2.53485364e+03, 1.63715002e+07, 6.46259650e+07],
#        [2.46944033e+03, 1.62086661e+07, 6.47888644e+07],
#        [2.40634071e+03, 1.60474500e+07, 6.49501437e+07],
#        [2.34545719e+03, 1.58878358e+07, 6.51098188e+07],
#        [2.28669690e+03, 1.57298076e+07, 6.52679057e+07],
#        [2.22997141e+03, 1.55733499e+07, 6.54244202e+07],
#        [2.17519651e+03, 1.54184469e+07, 6.55793779e+07],
#        [2.12229198e+03, 1.52650835e+07, 6.57327942e+07],
#        [2.07118138e+03, 1.51132442e+07, 6.58846846e+07],
#        [2.02179185e+03, 1.49629141e+07, 6.60350642e+07]])

# %%
#Ploting
day = start_count_day + len(removed_observed) + 3
pl.plot(RES[:day,1], '--r', label='Infected Expected')
pl.plot(RES[:day,2], '--g', label='Recovered Expected')
pl.plot(infected_observed, '-r', label='Infected Observed')
pl.plot(removed_observed, '-g', label='Recovered Observed')

pl.legend(loc=0)
pl.title(chosen_country + ', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')
# Out:
# Text(0, 0.5, 'Infectious and Recovereds')

# %%
#Ploting
pl.plot(RES[:,0], '--b', label='Susceptibles')
pl.plot(RES[:,1], '--r', label='Infecteds')
pl.plot(RES[:,2], '--g', label='Recovereds')

pl.legend(loc=0)
pl.title(chosen_country + ', SIR Model')
pl.xlabel('Time')
pl.ylabel('Infectious and Recovereds')
# Out:
# Text(0, 0.5, 'Infectious and Recovereds')
